# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# U(x,t) has shape 201x201 for x in [-1,1] and t in [0,1]
U48=np.loadtxt('burgers_solution_test02_q48.txt')
U36=np.loadtxt('burgers_solution_test02_q36.txt')
#U12=np.loadtxt('burgers_solution_test02_q12.txt')

# %%
# collect solution at t=0.25, 0.5 and 0.75
# corresponding to 51st (indexed 50), 101st (indexed 100), and 151st (indexed 150) columns
u36=U36[:,np.array([50, 100, 150])]
u48=U48[:,np.array([50, 100, 150])]
np.save('u_exact.npy')

# %%
plt.plot(np.arange(-1.,1.01,0.01), u48[:,0])
plt.plot(np.arange(-1.,1.01,0.01), u36[:,0])

# %%
plt.plot(np.arange(-1.,1.01,0.01), u48[:,1])
plt.plot(np.arange(-1.,1.01,0.01), u36[:,1])

#plt.plot(np.arange(-1.,1.01,0.01), u12[:,1])

# %%
plt.plot(np.arange(-1.,1.01,0.01), u48[:,2])


#plt.plot(np.arange(-1.,1.01,0.01), u16[:,2])
#plt.plot(np.arange(-1.,1.01,0.01), u12[:,2])

# %%
plt.plot(np.arange(-1.,1.01,0.01), u36[:,2])

# %%
np.amax(u48-u36)
# Out:
# 8.699999999994823e-05

# %%
np.amin(u48-u36)
# Out:
# -8.699999999994823e-05
