# %%
import numpy as np
import math
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# Set data type
DTYPE=torch.float32

# Set constants
pi=torch.pi
#viscosity = .01/pi
viscosity=0.001

# Define initial condition
# The initial condition is a sine wave which should develop a shock wave later
def fun_u_0(x):
    return -torch.sin(pi * x)

# Define boundary condition
def fun_u_b(t, x):
    n = x.shape[0]
    return torch.zeros((n,1), dtype=DTYPE)

# Define residual of the PDE
def fun_r(t, x, u, u_t, u_x, u_xx):
    return u_t + u * u_x - viscosity * u_xx

# %%
# Set number of data points
N_0 = 100 # points for initial condition
N_b = 100 # points for boundary condition
N_r = 10000 # interior points

# Set boundary of simulation box
tmin = 0.
tmax = 1.
xmin = -1.
xmax = 1.



# Lower bounds
lb = torch.tensor([tmin, xmin], dtype=DTYPE)
# Upper bounds
ub = torch.tensor([tmax, xmax], dtype=DTYPE)

# Set random seed for reproducible results
#torch.manual_seed(0)

# %%
# sample initial value
t_0=torch.ones((N_0,1),dtype=DTYPE)*lb[0]
x_0=torch.rand((N_0,1),dtype=DTYPE)

# scale x_0 to between x_min and x_max
x_0=x_0*(ub[1]-lb[1]) + lb[1]

# concatenate t_0 and x_0 into an N_0 x 2 matrix
X_0 = torch.cat([t_0, x_0], axis=1)


# Evaluate intitial condition at x_0
u_0 = fun_u_0(x_0)

#u_0.shape is torch.Size([50, 1])

# %%
# Boundary data
t_b = torch.rand((N_b,1), dtype=DTYPE)
t_b = t_b*(ub[0] - lb[0])+lb[0]
x_b = lb[1] + (ub[1] - lb[1]) * torch.bernoulli(torch.ones((N_b,1))-1/2)
# or we can just create two N_b/2 by 1 tensors, one for each boundary


# concatenate to an N_b x 2 matrix
X_b = torch.cat([t_b, x_b], axis=1)


# Evaluate boundary condition at (t_b,x_b)
u_b = fun_u_b(t_b, x_b)

# %%
# Draw uniformly sampled collocation points
t_r = torch.rand((N_r,1),dtype=DTYPE)
t_r = t_r*(ub[0]-lb[0])+lb[0]
x_r = torch.rand((N_r,1),dtype=DTYPE)
x_r = x_r*(ub[1]-lb[1])+lb[1]
X_r = torch.cat([t_r, x_r], axis=1)



# Collect boundary and inital data in lists
X_data = [X_0, X_b]
u_data = [u_0, u_b]

# X_data[0].shape is torch.Size([50, 2])

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(9,6))
plt.scatter(t_0, x_0, c=u_0, marker='X', vmin=-1, vmax=1)
plt.scatter(t_b, x_b, c=u_b, marker='X', vmin=-1, vmax=1)
plt.scatter(t_r, x_r, c='r', marker='.', alpha=0.1)
plt.xlabel('$t$')
plt.ylabel('$x$')

plt.title('Positions of collocation points and boundary data');
#plt.savefig('Xdata_Burgers.pdf', bbox_inches='tight', dpi=300)

# %%
# Define neural network architecture

def init_model(num_hidden_layers=8, num_neurons_per_layer=20):
    layers = []
    layers.append(nn.Linear(2, 20))
    layers.append(nn.Tanh())
    for _ in range(num_hidden_layers):
        layers.append(nn.Linear(20,20))
        layers.append(nn.Tanh())
    layers.append(nn.Linear(20, 1))

    model = nn.Sequential(*layers)
    return model

# %%
# compute residual in the bulk
# X_r is a (N_r x 2) torch tensor

def get_r(model, X_r):
    
    t, x = X_r[:, 0:1], X_r[:,1:2]
    # this way of slicing makes t and x both (N_r x 1) tensor
    # and NOT a [N_r] vector
    
    t.requires_grad_(requires_grad=True)
    x.requires_grad_(requires_grad=True)
    
    u = model(torch.stack([t[:,0], x[:,0]], axis=1))
    # torch.stack([t[:,0], x[:,0]], axis=1) has shape (N_r x 2)
    # u has shape (N_r x 1)
    
    u_t=torch.autograd.grad(u,t,torch.ones_like(u),create_graph=True)[0]
    u_x=torch.autograd.grad(u,x,torch.ones_like(u),create_graph=True)[0]
    u_xx=torch.autograd.grad(u_x,x,torch.ones_like(u_x),create_graph=True)[0]
    # all derivatives have shape (N_r x 1) because of torch.ones_like(u)
    
    return fun_r(t, x, u, u_t, u_x, u_xx)

# %%
from torch.utils.data import Dataset

# Data for the bulk collocation points
# no label
# X_r is a (N_r x 2) tensor with features x and t

class FunctionDataset_r(Dataset):
    
    def __init__(self,X_r):
        self.X_r = X_r    
        self.N_r = len(X_r) 
        
    def __getitem__(self,index):
        return self.X_r[index] 
    
    def __len__(self):
        return self.N_r

    
# Data for the initial and boundary points
# with labels
# X_data is a list, X_data[0] and X_data[1] are (50 x 2) tensor
# corresponding to initial and boundary points

class FunctionDataset_b(Dataset):
    
    def __init__(self,X_data,u_data):
        self.X_data = X_data   
        self.u_data = u_data 
        self.N_data = len(X_data)  
        
    def __getitem__(self,index):
        return self.X_data[index],self.u_data[index]
    
    def __len__(self):
        return self.N_data

function_dataset_r = FunctionDataset_r(X_r)
function_dataset_b = FunctionDataset_b(X_data,u_data)

train_dataloader_r = DataLoader(function_dataset_r,batch_size = 1000,shuffle=True)
train_dataloader_b = DataLoader(function_dataset_b,batch_size = len(function_dataset_b),shuffle=True)

# %%
# Initialize model aka u_\theta
model = init_model()

# %%
def train(net, epochs, train_dataloader_r,train_dataloader_b,get_r):
    
    
    criterion = nn.MSELoss(reduction = 'mean')
    
    optimizer = optim.Adam(net.parameters(), lr=1e-2)

    # Adam = adaptive momentum optimizer
    # SGD = stastic gradient descent optimizer
    
    
    for epoch in range(epochs): 
        running_loss = 0.0
        if epoch == 1000:
            optimizer = optim.Adam(net.parameters(), lr=1e-3)
        elif epoch == 3000:
            optimizer = optim.Adam(net.parameters(), lr=5e-4)
        elif epoch == 5000:
            optimizer = optim.Adam(net.parameters(), lr=2e-4)
        elif epoch == 7000:
            optimizer = optim.Adam(net.parameters(), lr=1e-4)
        elif epoch == 15000:
            optimizer = optim.Adam(net.parameters(), lr=5e-5)
    
        for i,X_r in enumerate(train_dataloader_r):
            for j,(X_data,u_data) in enumerate(train_dataloader_b):
                optimizer.zero_grad()
                A = get_r(net,X_r)
                loss1 = criterion(A,torch.zeros(A.shape))
                outputs = net(X_data)
                loss2 = criterion(outputs,u_data)
            
                loss = loss1 + 15*loss2
                loss.backward()
                optimizer.step()

        # print statistics
        running_loss += loss.item()
        print('epoch')
        print(epoch)
        print('running_loss')
        print(running_loss)
    print('Finished Training',running_loss, loss2.item())

# %%
train(model, 8000, train_dataloader_r,train_dataloader_b,get_r)
# Out:
# epoch
# 0
# running_loss
# 2.3427655696868896
# epoch
# 1
# running_loss
# 2.29472017288208
# epoch
# 2
# running_loss
# 2.267008066177368
# epoch
# 3
# running_loss
# 2.344395637512207
# epoch
# 4
# running_loss
# 2.2565884590148926
# epoch
# 5
# running_loss
# 2.2467854022979736
# epoch
# 6
# running_loss
# 2.2298545837402344
# epoch
# 7
# running_loss
# 2.0390422344207764
# epoch
# 8
# running_loss
# 1.2757768630981445
# epoch
# 9
# running_loss
# 1.0623712539672852
# epoch
# 10
# running_loss
# 1.2937337160110474
# epoch
# 11
# running_loss
# 0.7367550730705261
# epoch
# 12
# running_loss
# 0.6231522560119629
# epoch
# 13
# running_loss
# 0.46906930208206177
# epoch
# 14
# running_loss
# 0.4396008253097534
# epoch
# 15
# running_loss
# 0.34291213750839233
# epoch
# 16
# running_loss
# 0.318269819021225
# epoch
# 17
# running_loss
# 0.3178776502609253
# epoch
# 18
# running_loss
# 0.29338061809539795
# epoch
# 19
# running_loss
# 0.2851502001285553
# epoch
# 20
# running_loss
# 0.2667762041091919
# epoch
# 21
# running_loss
# 0.25397253036499023
# epoch
# 22
# running_loss
# 0.25705403089523315
# epoch
# 23
# running_loss
# 0.2514767348766327
# epoch
# 24
# running_loss
# 0.23809227347373962
# epoch
# 25
# running_loss
# 0.2642129957675934
# epoch
# 26
# running_loss
# 0.22432351112365723
# epoch
# 27
# running_loss
# 0.2271769642829895
# epoch
# 28
# running_loss
# 0.25554418563842773
# epoch
# 29
# running_loss
# 0.22340822219848633
# epoch
# 30
# running_loss
# 0.2233545184135437
# epoch
# 31
# running_loss
# 0.2290397733449936
# epoch
# 32
# running_loss
# 0.21312128007411957
# epoch
# 33
# running_loss
# 0.23129892349243164
# epoch
# 34
# running_loss
# 0.22111091017723083
# epoch
# 35
# running_loss
# 0.2367175817489624
# epoch
# 36
# running_loss
# 0.20561744272708893
# epoch
# 37
# running_loss
# 0.21560417115688324
# epoch
# 38
# running_loss
# 0.20307685434818268
# epoch
# 39
# running_loss
# 0.25014728307724
# epoch
# 40
# running_loss
# 0.24753929674625397
# epoch
# 41
# running_loss
# 0.267696738243103
# epoch
# 42
# running_loss
# 0.20958146452903748
# epoch
# 43
# running_loss
# 0.2544025182723999
# epoch
# 44
# running_loss
# 0.21769829094409943
# epoch
# 45
# running_loss
# 0.28372836112976074
# epoch
# 46
# running_loss
# 0.2541625499725342
# epoch
# 47
# running_loss
# 0.2323601096868515
# epoch
# 48
# running_loss
# 0.203008770942688
# epoch
# 49
# running_loss
# 0.9614700078964233
# epoch
# 50
# running_loss
# 1.4604480266571045
# epoch
# 51
# running_loss
# 1.0458272695541382
# epoch
# 52
# running_loss
# 0.5916576385498047
# epoch
# 53
# running_loss
# 0.449297696352005
# epoch
# 54
# running_loss
# 0.32856839895248413
# epoch
# 55
# running_loss
# 0.28020790219306946
# epoch
# 56
# running_loss
# 0.26602667570114136
# epoch
# 57
# running_loss
# 0.22706453502178192
# epoch
# 58
# running_loss
# 0.22815601527690887
# epoch
# 59
# running_loss
# 0.22793638706207275
# epoch
# 60
# running_loss
# 0.24722088873386383
# epoch
# 61
# running_loss
# 0.23205040395259857
# epoch
# 62
# running_loss
# 0.23293928802013397
# epoch
# 63
# running_loss
# 0.21562884747982025
# epoch
# 64
# running_loss
# 0.2124820351600647
# epoch
# 65
# running_loss
# 0.24217331409454346
# epoch
# 66
# running_loss
# 0.23251500725746155
# epoch
# 67
# running_loss
# 0.23803244531154633
# epoch
# 68
# running_loss
# 0.23654994368553162
# epoch
# 69
# running_loss
# 0.2462373971939087
# epoch
# 70
# running_loss
# 0.20561206340789795
# epoch
# 71
# running_loss
# 0.21040752530097961
# epoch
# 72
# running_loss
# 0.2274804562330246
# epoch
# 73
# running_loss
# 0.20878775417804718
# epoch
# 74
# running_loss
# 0.2204170823097229
# epoch
# 75
# running_loss
# 0.2075956165790558
# epoch
# 76
# running_loss
# 0.19623112678527832
# epoch
# 77
# running_loss
# 0.2465386986732483
# epoch
# 78
# running_loss
# 0.2100236713886261
# epoch
# 79
# running_loss
# 0.19456711411476135
# epoch
# 80
# running_loss
# 0.21799275279045105
# epoch
# 81
# running_loss
# 0.2177014946937561
# epoch
# 82
# running_loss
# 0.3456922173500061
# epoch
# 83
# running_loss
# 0.25019365549087524
# epoch
# 84
# running_loss
# 0.37030163407325745
# epoch
# 85
# running_loss
# 0.29781875014305115
# epoch
# 86
# running_loss
# 0.29022035002708435
# epoch
# 87
# running_loss
# 0.27086812257766724
# epoch
# 88
# running_loss
# 0.23175030946731567
# epoch
# 89
# running_loss
# 0.2254934459924698
# epoch
# 90
# running_loss
# 0.23449097573757172
# epoch
# 91
# running_loss
# 0.2255476713180542
# epoch
# 92
# running_loss
# 0.20623813569545746
# epoch
# 93
# running_loss
# 0.21741950511932373
# epoch
# 94
# running_loss
# 0.2156027853488922
# epoch
# 95
# running_loss
# 0.21446257829666138
# epoch
# 96
# running_loss
# 0.20376217365264893
# epoch
# 97
# running_loss
# 0.19336985051631927
# epoch
# 98
# running_loss
# 0.2088930606842041
# epoch
# 99
# running_loss
# 0.1922023594379425
# epoch
# 100
# running_loss
# 0.1800948679447174
# epoch
# 101
# running_loss
# 0.1856456696987152
# epoch
# 102
# running_loss
# 0.18633387982845306
# epoch
# 103
# running_loss
# 0.19873155653476715
# epoch
# 104
# running_loss
# 0.18930530548095703
# epoch
# 105
# running_loss
# 1.0205320119857788
# epoch
# 106
# running_loss
# 2.679964303970337
# epoch
# 107
# running_loss
# 2.202007293701172
# epoch
# 108
# running_loss
# 2.6352698802948
# epoch
# 109
# running_loss
# 2.1838128566741943
# epoch
# 110
# running_loss
# 1.908599615097046
# epoch
# 111
# running_loss
# 1.3034605979919434
# epoch
# 112
# running_loss
# 1.1823793649673462
# epoch
# 113
# running_loss
# 1.0824965238571167
# epoch
# 114
# running_loss
# 0.8878863453865051
# epoch
# 115
# running_loss
# 0.8365367650985718
# epoch
# 116
# running_loss
# 0.7487319707870483
# epoch
# 117
# running_loss
# 0.4051317870616913
# epoch
# 118
# running_loss
# 0.3587513566017151
# epoch
# 119
# running_loss
# 0.30079758167266846
# epoch
# 120
# running_loss
# 0.3007499575614929
# epoch
# 121
# running_loss
# 0.2878897190093994
# epoch
# 122
# running_loss
# 0.2686269283294678
# epoch
# 123
# running_loss
# 0.2616675794124603
# epoch
# 124
# running_loss
# 0.2743853032588959
# epoch
# 125
# running_loss
# 0.2726482152938843
# epoch
# 126
# running_loss
# 0.24509015679359436
# epoch
# 127
# running_loss
# 0.23920398950576782
# epoch
# 128
# running_loss
# 0.2523975968360901
# epoch
# 129
# running_loss
# 0.2421262562274933
# epoch
# 130
# running_loss
# 0.24875721335411072
# epoch
# 131
# running_loss
# 0.27759629487991333
# epoch
# 132
# running_loss
# 0.23111647367477417
# epoch
# 133
# running_loss
# 0.235769122838974
# epoch
# 134
# running_loss
# 0.23181743919849396
# epoch
# 135
# running_loss
# 0.2366872876882553
# epoch
# 136
# running_loss
# 0.21852785348892212
# epoch
# 137
# running_loss
# 0.22981330752372742
# epoch
# 138
# running_loss
# 0.25720158219337463
# epoch
# 139
# running_loss
# 0.25705695152282715
# epoch
# 140
# running_loss
# 0.24742145836353302
# epoch
# 141
# running_loss
# 0.23287686705589294
# epoch
# 142
# running_loss
# 0.22609367966651917
# epoch
# 143
# running_loss
# 0.2820550501346588
# epoch
# 144
# running_loss
# 0.24381786584854126
# epoch
# 145
# running_loss
# 0.21288339793682098
# epoch
# 146
# running_loss
# 0.24776387214660645
# epoch
# 147
# running_loss
# 0.22730138897895813
# epoch
# 148
# running_loss
# 0.24971455335617065
# epoch
# 149
# running_loss
# 0.22064870595932007
# epoch
# 150
# running_loss
# 0.2647527754306793
# epoch
# 151
# running_loss
# 0.21431449055671692
# epoch
# 152
# running_loss
# 0.21452432870864868
# epoch
# 153
# running_loss
# 0.2267533242702484
# epoch
# 154
# running_loss
# 0.2339782863855362
# epoch
# 155
# running_loss
# 0.24340477585792542
# epoch
# 156
# running_loss
# 0.2403605878353119
# epoch
# 157
# running_loss
# 0.21194203197956085
# epoch
# 158
# running_loss
# 0.23280861973762512
# epoch
# 159
# running_loss
# 0.24736279249191284
# epoch
# 160
# running_loss
# 0.225336492061615
# epoch
# 161
# running_loss
# 0.23227840662002563
# epoch
# 162
# running_loss
# 0.23751094937324524
# epoch
# 163
# running_loss
# 0.24490886926651
# epoch
# 164
# running_loss
# 0.21345870196819305
# epoch
# 165
# running_loss
# 0.21413357555866241
# epoch
# 166
# running_loss
# 0.25225013494491577
# epoch
# 167
# running_loss
# 0.2758711576461792
# epoch
# 168
# running_loss
# 0.22109423577785492
# epoch
# 169
# running_loss
# 0.2043476402759552
# epoch
# 170
# running_loss
# 0.20116031169891357
# epoch
# 171
# running_loss
# 0.19076105952262878
# epoch
# 172
# running_loss
# 0.19160515069961548
# epoch
# 173
# running_loss
# 0.20453181862831116
# epoch
# 174
# running_loss
# 0.21165922284126282
# epoch
# 175
# running_loss
# 0.21221664547920227
# epoch
# 176
# running_loss
# 0.21230751276016235
# epoch
# 177
# running_loss
# 0.23718109726905823
# epoch
# 178
# running_loss
# 0.46823185682296753
# epoch
# 179
# running_loss
# 0.4611421823501587
# epoch
# 180
# running_loss
# 0.3149756193161011
# epoch
# 181
# running_loss
# 0.30942249298095703
# epoch
# 182
# running_loss
# 0.23351538181304932
# epoch
# 183
# running_loss
# 0.20447281002998352
# epoch
# 184
# running_loss
# 0.2022576630115509
# epoch
# 185
# running_loss
# 0.17982181906700134
# epoch
# 186
# running_loss
# 0.17708972096443176
# epoch
# 187
# running_loss
# 0.37737521529197693
# epoch
# 188
# running_loss
# 0.3671051859855652
# epoch
# 189
# running_loss
# 0.2612708806991577
# epoch
# 190
# running_loss
# 0.20288021862506866
# epoch
# 191
# running_loss
# 0.19528231024742126
# epoch
# 192
# running_loss
# 0.17849963903427124
# epoch
# 193
# running_loss
# 1.6027766466140747
# epoch
# 194
# running_loss
# 0.8050442934036255
# epoch
# 195
# running_loss
# 0.5038644075393677
# epoch
# 196
# running_loss
# 0.429115355014801
# epoch
# 197
# running_loss
# 0.3541907072067261
# epoch
# 198
# running_loss
# 0.3418066203594208
# epoch
# 199
# running_loss
# 0.2940783202648163
# epoch
# 200
# running_loss
# 0.27458131313323975
# epoch
# 201
# running_loss
# 0.25778722763061523
# epoch
# 202
# running_loss
# 0.2550440728664398
# epoch
# 203
# running_loss
# 0.24796104431152344
# epoch
# 204
# running_loss
# 0.2403779923915863
# epoch
# 205
# running_loss
# 0.3138914704322815
# epoch
# 206
# running_loss
# 0.31165632605552673
# epoch
# 207
# running_loss
# 0.24933521449565887
# epoch
# 208
# running_loss
# 0.2349807322025299
# epoch
# 209
# running_loss
# 0.23487713932991028
# epoch
# 210
# running_loss
# 0.22252938151359558
# epoch
# 211
# running_loss
# 0.22017589211463928
# epoch
# 212
# running_loss
# 0.2180698961019516
# epoch
# 213
# running_loss
# 0.22021542489528656
# epoch
# 214
# running_loss
# 0.2216101884841919
# epoch
# 215
# running_loss
# 0.19763219356536865
# epoch
# 216
# running_loss
# 0.21676938235759735
# epoch
# 217
# running_loss
# 0.19114276766777039
# epoch
# 218
# running_loss
# 0.20813487470149994
# epoch
# 219
# running_loss
# 0.2289743423461914
# epoch
# 220
# running_loss
# 0.20165349543094635
# epoch
# 221
# running_loss
# 0.20539960265159607
# epoch
# 222
# running_loss
# 0.1878894716501236
# epoch
# 223
# running_loss
# 0.22271348536014557
# epoch
# 224
# running_loss
# 0.26149022579193115
# epoch
# 225
# running_loss
# 0.23654112219810486
# epoch
# 226
# running_loss
# 0.22839410603046417
# epoch
# 227
# running_loss
# 0.20225299894809723
# epoch
# 228
# running_loss
# 0.20967957377433777
# epoch
# 229
# running_loss
# 0.22181811928749084
# epoch
# 230
# running_loss
# 0.20727120339870453
# epoch
# 231
# running_loss
# 0.18649506568908691
# epoch
# 232
# running_loss
# 0.19393151998519897
# epoch
# 233
# running_loss
# 0.18939614295959473
# epoch
# 234
# running_loss
# 0.19971062242984772
# epoch
# 235
# running_loss
# 0.21017810702323914
# epoch
# 236
# running_loss
# 0.19644547998905182
# epoch
# 237
# running_loss
# 0.20809298753738403
# epoch
# 238
# running_loss
# 0.20222324132919312
# epoch
# 239
# running_loss
# 0.19851091504096985
# epoch
# 240
# running_loss
# 0.2250322699546814
# epoch
# 241
# running_loss
# 0.19617652893066406
# epoch
# 242
# running_loss
# 0.20424355566501617
# epoch
# 243
# running_loss
# 0.22493970394134521
# epoch
# 244
# running_loss
# 0.18399935960769653
# epoch
# 245
# running_loss
# 0.18049731850624084
# epoch
# 246
# running_loss
# 0.184797465801239
# epoch
# 247
# running_loss
# 0.17148318886756897
# epoch
# 248
# running_loss
# 0.28474000096321106
# epoch
# 249
# running_loss
# 0.22216325998306274
# epoch
# 250
# running_loss
# 0.1958988457918167
# epoch
# 251
# running_loss
# 0.199046328663826
# epoch
# 252
# running_loss
# 0.1834966540336609
# epoch
# 253
# running_loss
# 0.19563034176826477
# epoch
# 254
# running_loss
# 0.19273045659065247
# epoch
# 255
# running_loss
# 0.20484879612922668
# epoch
# 256
# running_loss
# 0.19097940623760223
# epoch
# 257
# running_loss
# 0.1721329689025879
# epoch
# 258
# running_loss
# 0.1816425323486328
# epoch
# 259
# running_loss
# 0.2215636819601059
# epoch
# 260
# running_loss
# 0.21334028244018555
# epoch
# 261
# running_loss
# 0.5015890598297119
# epoch
# 262
# running_loss
# 0.42751580476760864
# epoch
# 263
# running_loss
# 0.29467976093292236
# epoch
# 264
# running_loss
# 0.25333699584007263
# epoch
# 265
# running_loss
# 0.23319420218467712
# epoch
# 266
# running_loss
# 0.23526476323604584
# epoch
# 267
# running_loss
# 0.23246610164642334
# epoch
# 268
# running_loss
# 0.21675369143486023
# epoch
# 269
# running_loss
# 0.20731110870838165
# epoch
# 270
# running_loss
# 0.19395697116851807
# epoch
# 271
# running_loss
# 0.19298936426639557
# epoch
# 272
# running_loss
# 0.1940889060497284
# epoch
# 273
# running_loss
# 0.19744744896888733
# epoch
# 274
# running_loss
# 0.18394845724105835
# epoch
# 275
# running_loss
# 0.18311002850532532
# epoch
# 276
# running_loss
# 0.19592085480690002
# epoch
# 277
# running_loss
# 0.2014937698841095
# epoch
# 278
# running_loss
# 2.253896951675415
# epoch
# 279
# running_loss
# 2.883859634399414
# epoch
# 280
# running_loss
# 2.3136367797851562
# epoch
# 281
# running_loss
# 1.3887360095977783
# epoch
# 282
# running_loss
# 1.0508928298950195
# epoch
# 283
# running_loss
# 0.968889594078064
# epoch
# 284
# running_loss
# 0.8821505904197693
# epoch
# 285
# running_loss
# 2.065145969390869
# epoch
# 286
# running_loss
# 1.6335694789886475
# epoch
# 287
# running_loss
# 0.7961147427558899
# epoch
# 288
# running_loss
# 0.5685352087020874
# epoch
# 289
# running_loss
# 0.40572571754455566
# epoch
# 290
# running_loss
# 0.31739071011543274
# epoch
# 291
# running_loss
# 0.4789896607398987
# epoch
# 292
# running_loss
# 0.2827131152153015
# epoch
# 293
# running_loss
# 0.27557480335235596
# epoch
# 294
# running_loss
# 0.2862531542778015
# epoch
# 295
# running_loss
# 0.34660738706588745
# epoch
# 296
# running_loss
# 0.27120235562324524
# epoch
# 297
# running_loss
# 0.2732100188732147
# epoch
# 298
# running_loss
# 0.2438569962978363
# epoch
# 299
# running_loss
# 0.3985714912414551
# epoch
# 300
# running_loss
# 0.2985718250274658
# epoch
# 301
# running_loss
# 0.26188308000564575
# epoch
# 302
# running_loss
# 0.24609529972076416
# epoch
# 303
# running_loss
# 0.254839152097702
# epoch
# 304
# running_loss
# 0.2579895257949829
# epoch
# 305
# running_loss
# 0.2151399403810501
# epoch
# 306
# running_loss
# 0.2308032065629959
# epoch
# 307
# running_loss
# 0.2547144889831543
# epoch
# 308
# running_loss
# 0.24449899792671204
# epoch
# 309
# running_loss
# 0.2267163097858429
# epoch
# 310
# running_loss
# 0.2254619300365448
# epoch
# 311
# running_loss
# 0.22025153040885925
# epoch
# 312
# running_loss
# 0.23054085671901703
# epoch
# 313
# running_loss
# 0.23501470685005188
# epoch
# 314
# running_loss
# 0.2377391904592514
# epoch
# 315
# running_loss
# 0.24446836113929749
# epoch
# 316
# running_loss
# 0.22648948431015015
# epoch
# 317
# running_loss
# 0.21751272678375244
# epoch
# 318
# running_loss
# 0.23751091957092285
# epoch
# 319
# running_loss
# 0.22525815665721893
# epoch
# 320
# running_loss
# 0.21667808294296265
# epoch
# 321
# running_loss
# 0.22656701505184174
# epoch
# 322
# running_loss
# 0.21608339250087738
# epoch
# 323
# running_loss
# 0.2281688153743744
# epoch
# 324
# running_loss
# 0.22013433277606964
# epoch
# 325
# running_loss
# 0.22082506120204926
# epoch
# 326
# running_loss
# 0.22141055762767792
# epoch
# 327
# running_loss
# 0.2183701992034912
# epoch
# 328
# running_loss
# 0.20556645095348358
# epoch
# 329
# running_loss
# 0.2144848108291626
# epoch
# 330
# running_loss
# 0.23296751081943512
# epoch
# 331
# running_loss
# 0.2211390733718872
# epoch
# 332
# running_loss
# 0.21943984925746918
# epoch
# 333
# running_loss
# 0.23863689601421356
# epoch
# 334
# running_loss
# 0.21722345054149628
# epoch
# 335
# running_loss
# 0.23945777118206024
# epoch
# 336
# running_loss
# 0.1990348994731903
# epoch
# 337
# running_loss
# 0.2156813144683838
# epoch
# 338
# running_loss
# 0.21691350638866425
# epoch
# 339
# running_loss
# 0.2175927311182022
# epoch
# 340
# running_loss
# 0.22264620661735535
# epoch
# 341
# running_loss
# 0.2128007858991623
# epoch
# 342
# running_loss
# 0.21101999282836914
# epoch
# 343
# running_loss
# 0.23621812462806702
# epoch
# 344
# running_loss
# 0.20072707533836365
# epoch
# 345
# running_loss
# 0.20219188928604126
# epoch
# 346
# running_loss
# 0.2016909271478653
# epoch
# 347
# running_loss
# 0.20522114634513855
# epoch
# 348
# running_loss
# 0.19713127613067627
# epoch
# 349
# running_loss
# 0.21282343566417694
# epoch
# 350
# running_loss
# 0.19066253304481506
# epoch
# 351
# running_loss
# 0.20309001207351685
# epoch
# 352
# running_loss
# 0.26478952169418335
# epoch
# 353
# running_loss
# 0.219642773270607
# epoch
# 354
# running_loss
# 0.2007492631673813
# epoch
# 355
# running_loss
# 0.21305984258651733
# epoch
# 356
# running_loss
# 0.19035190343856812
# epoch
# 357
# running_loss
# 0.20994023978710175
# epoch
# 358
# running_loss
# 0.19396252930164337
# epoch
# 359
# running_loss
# 0.23110395669937134
# epoch
# 360
# running_loss
# 0.20191574096679688
# epoch
# 361
# running_loss
# 0.20888440310955048
# epoch
# 362
# running_loss
# 0.248712420463562
# epoch
# 363
# running_loss
# 0.20165398716926575
# epoch
# 364
# running_loss
# 0.3560768961906433
# epoch
# 365
# running_loss
# 0.23023250699043274
# epoch
# 366
# running_loss
# 0.20607104897499084
# epoch
# 367
# running_loss
# 0.22494012117385864
# epoch
# 368
# running_loss
# 0.19567811489105225
# epoch
# 369
# running_loss
# 0.16577458381652832
# epoch
# 370
# running_loss
# 0.1823642998933792
# epoch
# 371
# running_loss
# 0.21798396110534668
# epoch
# 372
# running_loss
# 0.3203335106372833
# epoch
# 373
# running_loss
# 0.3062923550605774
# epoch
# 374
# running_loss
# 0.24744778871536255
# epoch
# 375
# running_loss
# 0.22223679721355438
# epoch
# 376
# running_loss
# 0.19948846101760864
# epoch
# 377
# running_loss
# 0.19192394614219666
# epoch
# 378
# running_loss
# 0.1956551969051361
# epoch
# 379
# running_loss
# 0.4383557140827179
# epoch
# 380
# running_loss
# 0.24391181766986847
# epoch
# 381
# running_loss
# 0.2090136706829071
# epoch
# 382
# running_loss
# 0.21501551568508148
# epoch
# 383
# running_loss
# 0.19703659415245056
# epoch
# 384
# running_loss
# 0.21137982606887817
# epoch
# 385
# running_loss
# 0.20773619413375854
# epoch
# 386
# running_loss
# 0.17597970366477966
# epoch
# 387
# running_loss
# 0.2170305848121643
# epoch
# 388
# running_loss
# 0.2371707260608673
# epoch
# 389
# running_loss
# 0.2675023078918457
# epoch
# 390
# running_loss
# 0.1797615885734558
# epoch
# 391
# running_loss
# 0.1996012032032013
# epoch
# 392
# running_loss
# 0.23448553681373596
# epoch
# 393
# running_loss
# 0.21989886462688446
# epoch
# 394
# running_loss
# 0.20393714308738708
# epoch
# 395
# running_loss
# 0.24129672348499298
# epoch
# 396
# running_loss
# 0.2789892256259918
# epoch
# 397
# running_loss
# 0.3618825078010559
# epoch
# 398
# running_loss
# 0.38359373807907104
# epoch
# 399
# running_loss
# 0.26485711336135864
# epoch
# 400
# running_loss
# 0.20943255722522736
# epoch
# 401
# running_loss
# 0.20679739117622375
# epoch
# 402
# running_loss
# 0.20916886627674103
# epoch
# 403
# running_loss
# 0.2661454379558563
# epoch
# 404
# running_loss
# 0.28290337324142456
# epoch
# 405
# running_loss
# 0.2905852794647217
# epoch
# 406
# running_loss
# 0.25891435146331787
# epoch
# 407
# running_loss
# 0.2015582174062729
# epoch
# 408
# running_loss
# 0.1743067502975464
# epoch
# 409
# running_loss
# 0.3300620913505554
# epoch
# 410
# running_loss
# 0.35815128684043884
# epoch
# 411
# running_loss
# 0.2103334367275238
# epoch
# 412
# running_loss
# 0.21098527312278748
# epoch
# 413
# running_loss
# 0.2099321186542511
# epoch
# 414
# running_loss
# 0.26571083068847656
# epoch
# 415
# running_loss
# 0.422441303730011
# epoch
# 416
# running_loss
# 0.4102713465690613
# epoch
# 417
# running_loss
# 0.30642861127853394
# epoch
# 418
# running_loss
# 0.28698456287384033
# epoch
# 419
# running_loss
# 0.2754494845867157
# epoch
# 420
# running_loss
# 0.21877573430538177
# epoch
# 421
# running_loss
# 0.21037687361240387
# epoch
# 422
# running_loss
# 0.2770789861679077
# epoch
# 423
# running_loss
# 0.19928613305091858
# epoch
# 424
# running_loss
# 0.17828692495822906
# epoch
# 425
# running_loss
# 0.195003941655159
# epoch
# 426
# running_loss
# 0.17657476663589478
# epoch
# 427
# running_loss
# 0.16543839871883392
# epoch
# 428
# running_loss
# 0.251604288816452
# epoch
# 429
# running_loss
# 0.23133006691932678
# epoch
# 430
# running_loss
# 0.22979912161827087
# epoch
# 431
# running_loss
# 0.22827419638633728
# epoch
# 432
# running_loss
# 0.2056116759777069
# epoch
# 433
# running_loss
# 0.620110034942627
# epoch
# 434
# running_loss
# 0.46697720885276794
# epoch
# 435
# running_loss
# 0.3284473121166229
# epoch
# 436
# running_loss
# 0.28300705552101135
# epoch
# 437
# running_loss
# 0.3001943826675415
# epoch
# 438
# running_loss
# 0.274656742811203
# epoch
# 439
# running_loss
# 0.2514096796512604
# epoch
# 440
# running_loss
# 0.2581245005130768
# epoch
# 441
# running_loss
# 0.26180300116539
# epoch
# 442
# running_loss
# 0.2507825195789337
# epoch
# 443
# running_loss
# 0.2532377243041992
# epoch
# 444
# running_loss
# 0.23108994960784912
# epoch
# 445
# running_loss
# 0.2254045456647873
# epoch
# 446
# running_loss
# 0.23632870614528656
# epoch
# 447
# running_loss
# 0.2288753092288971
# epoch
# 448
# running_loss
# 0.22280974686145782
# epoch
# 449
# running_loss
# 0.21916230022907257
# epoch
# 450
# running_loss
# 0.23614472150802612
# epoch
# 451
# running_loss
# 0.20598748326301575
# epoch
# 452
# running_loss
# 0.2207927256822586
# epoch
# 453
# running_loss
# 0.24097906053066254
# epoch
# 454
# running_loss
# 0.21210895478725433
# epoch
# 455
# running_loss
# 0.19380779564380646
# epoch
# 456
# running_loss
# 0.20898790657520294
# epoch
# 457
# running_loss
# 0.20586055517196655
# epoch
# 458
# running_loss
# 0.23630353808403015
# epoch
# 459
# running_loss
# 0.2205529808998108
# epoch
# 460
# running_loss
# 0.21348625421524048
# epoch
# 461
# running_loss
# 0.20068100094795227
# epoch
# 462
# running_loss
# 0.1859000325202942
# epoch
# 463
# running_loss
# 0.21511109173297882
# epoch
# 464
# running_loss
# 0.2077222764492035
# epoch
# 465
# running_loss
# 0.21901273727416992
# epoch
# 466
# running_loss
# 0.2312774360179901
# epoch
# 467
# running_loss
# 0.23212136328220367
# epoch
# 468
# running_loss
# 0.2068217396736145
# epoch
# 469
# running_loss
# 0.21586063504219055
# epoch
# 470
# running_loss
# 0.18915297091007233
# epoch
# 471
# running_loss
# 0.19629576802253723
# epoch
# 472
# running_loss
# 0.21782755851745605
# epoch
# 473
# running_loss
# 0.19101493060588837
# epoch
# 474
# running_loss
# 0.16973979771137238
# epoch
# 475
# running_loss
# 0.2816717028617859
# epoch
# 476
# running_loss
# 0.3338318169116974
# epoch
# 477
# running_loss
# 0.2940284311771393
# epoch
# 478
# running_loss
# 0.24214327335357666
# epoch
# 479
# running_loss
# 0.23072141408920288
# epoch
# 480
# running_loss
# 0.21348577737808228
# epoch
# 481
# running_loss
# 0.2019405961036682
# epoch
# 482
# running_loss
# 0.20892177522182465
# epoch
# 483
# running_loss
# 0.21769246459007263
# epoch
# 484
# running_loss
# 0.19453658163547516
# epoch
# 485
# running_loss
# 0.1812501847743988
# epoch
# 486
# running_loss
# 0.16227592527866364
# epoch
# 487
# running_loss
# 0.20206263661384583
# epoch
# 488
# running_loss
# 0.5554506182670593
# epoch
# 489
# running_loss
# 0.48728495836257935
# epoch
# 490
# running_loss
# 0.28054583072662354
# epoch
# 491
# running_loss
# 0.2422223836183548
# epoch
# 492
# running_loss
# 0.23498842120170593
# epoch
# 493
# running_loss
# 0.21726182103157043
# epoch
# 494
# running_loss
# 0.18747162818908691
# epoch
# 495
# running_loss
# 0.2067706286907196
# epoch
# 496
# running_loss
# 0.20187842845916748
# epoch
# 497
# running_loss
# 0.2030625343322754
# epoch
# 498
# running_loss
# 0.21140515804290771
# epoch
# 499
# running_loss
# 0.19125986099243164
# epoch
# 500
# running_loss
# 0.19136464595794678
# epoch
# 501
# running_loss
# 0.20505115389823914
# epoch
# 502
# running_loss
# 0.17818227410316467
# epoch
# 503
# running_loss
# 0.17304319143295288
# epoch
# 504
# running_loss
# 0.1808517873287201
# epoch
# 505
# running_loss
# 0.17453822493553162
# epoch
# 506
# running_loss
# 0.20440496504306793
# epoch
# 507
# running_loss
# 0.20247256755828857
# epoch
# 508
# running_loss
# 0.18407045304775238
# epoch
# 509
# running_loss
# 0.17773911356925964
# epoch
# 510
# running_loss
# 0.20253637433052063
# epoch
# 511
# running_loss
# 0.17862622439861298
# epoch
# 512
# running_loss
# 0.17995670437812805
# epoch
# 513
# running_loss
# 0.18120792508125305
# epoch
# 514
# running_loss
# 0.23598653078079224
# epoch
# 515
# running_loss
# 0.1742984801530838
# epoch
# 516
# running_loss
# 0.21375370025634766
# epoch
# 517
# running_loss
# 0.2550169825553894
# epoch
# 518
# running_loss
# 0.3323860764503479
# epoch
# 519
# running_loss
# 0.20819664001464844
# epoch
# 520
# running_loss
# 0.2120991200208664
# epoch
# 521
# running_loss
# 0.2102195769548416
# epoch
# 522
# running_loss
# 0.3739304542541504
# epoch
# 523
# running_loss
# 0.508796215057373
# epoch
# 524
# running_loss
# 0.40745633840560913
# epoch
# 525
# running_loss
# 0.31483757495880127
# epoch
# 526
# running_loss
# 0.2616429924964905
# epoch
# 527
# running_loss
# 0.2735874056816101
# epoch
# 528
# running_loss
# 0.2741926610469818
# epoch
# 529
# running_loss
# 0.23658275604248047
# epoch
# 530
# running_loss
# 0.25770288705825806
# epoch
# 531
# running_loss
# 0.23167024552822113
# epoch
# 532
# running_loss
# 0.22923436760902405
# epoch
# 533
# running_loss
# 0.23227478563785553
# epoch
# 534
# running_loss
# 0.21810829639434814
# epoch
# 535
# running_loss
# 0.21040299534797668
# epoch
# 536
# running_loss
# 0.2434937059879303
# epoch
# 537
# running_loss
# 0.22437456250190735
# epoch
# 538
# running_loss
# 0.20976440608501434
# epoch
# 539
# running_loss
# 0.24213632941246033
# epoch
# 540
# running_loss
# 0.21968211233615875
# epoch
# 541
# running_loss
# 0.19695015251636505
# epoch
# 542
# running_loss
# 0.23548534512519836
# epoch
# 543
# running_loss
# 0.2188902050256729
# epoch
# 544
# running_loss
# 0.20667670667171478
# epoch
# 545
# running_loss
# 0.204725980758667
# epoch
# 546
# running_loss
# 0.20709672570228577
# epoch
# 547
# running_loss
# 0.24425044655799866
# epoch
# 548
# running_loss
# 0.22151166200637817
# epoch
# 549
# running_loss
# 0.20694535970687866
# epoch
# 550
# running_loss
# 0.2059842050075531
# epoch
# 551
# running_loss
# 0.1916622668504715
# epoch
# 552
# running_loss
# 0.2061709463596344
# epoch
# 553
# running_loss
# 0.19539739191532135
# epoch
# 554
# running_loss
# 0.2160700559616089
# epoch
# 555
# running_loss
# 0.2212330400943756
# epoch
# 556
# running_loss
# 0.192820742726326
# epoch
# 557
# running_loss
# 0.2573487162590027
# epoch
# 558
# running_loss
# 0.21332377195358276
# epoch
# 559
# running_loss
# 0.20537489652633667
# epoch
# 560
# running_loss
# 0.21079286932945251
# epoch
# 561
# running_loss
# 0.20691409707069397
# epoch
# 562
# running_loss
# 0.22347813844680786
# epoch
# 563
# running_loss
# 0.23754915595054626
# epoch
# 564
# running_loss
# 0.21988871693611145
# epoch
# 565
# running_loss
# 0.20439413189888
# epoch
# 566
# running_loss
# 0.20392489433288574
# epoch
# 567
# running_loss
# 0.17959468066692352
# epoch
# 568
# running_loss
# 0.20068059861660004
# epoch
# 569
# running_loss
# 0.20180350542068481
# epoch
# 570
# running_loss
# 0.202043354511261
# epoch
# 571
# running_loss
# 0.18452633917331696
# epoch
# 572
# running_loss
# 0.17887116968631744
# epoch
# 573
# running_loss
# 0.1877584308385849
# epoch
# 574
# running_loss
# 0.18381492793560028
# epoch
# 575
# running_loss
# 0.21384665369987488
# epoch
# 576
# running_loss
# 0.20101624727249146
# epoch
# 577
# running_loss
# 0.20564192533493042
# epoch
# 578
# running_loss
# 0.22126458585262299
# epoch
# 579
# running_loss
# 0.22544312477111816
# epoch
# 580
# running_loss
# 0.20664963126182556
# epoch
# 581
# running_loss
# 0.2438892126083374
# epoch
# 582
# running_loss
# 0.31050199270248413
# epoch
# 583
# running_loss
# 0.2446403056383133
# epoch
# 584
# running_loss
# 0.21749044954776764
# epoch
# 585
# running_loss
# 0.21610301733016968
# epoch
# 586
# running_loss
# 0.20043611526489258
# epoch
# 587
# running_loss
# 0.19747063517570496
# epoch
# 588
# running_loss
# 0.18269899487495422
# epoch
# 589
# running_loss
# 0.19701112806797028
# epoch
# 590
# running_loss
# 0.19489531219005585
# epoch
# 591
# running_loss
# 0.1877208650112152
# epoch
# 592
# running_loss
# 0.22232303023338318
# epoch
# 593
# running_loss
# 0.22569236159324646
# epoch
# 594
# running_loss
# 0.22331786155700684
# epoch
# 595
# running_loss
# 0.22555476427078247
# epoch
# 596
# running_loss
# 0.19313642382621765
# epoch
# 597
# running_loss
# 0.19677311182022095
# epoch
# 598
# running_loss
# 0.18504875898361206
# epoch
# 599
# running_loss
# 0.18102017045021057
# epoch
# 600
# running_loss
# 0.1887737512588501
# epoch
# 601
# running_loss
# 0.19394050538539886
# epoch
# 602
# running_loss
# 0.19478465616703033
# epoch
# 603
# running_loss
# 0.18671561777591705
# epoch
# 604
# running_loss
# 0.20558930933475494
# epoch
# 605
# running_loss
# 0.20262335240840912
# epoch
# 606
# running_loss
# 0.28693050146102905
# epoch
# 607
# running_loss
# 0.22103990614414215
# epoch
# 608
# running_loss
# 0.21449941396713257
# epoch
# 609
# running_loss
# 0.20759063959121704
# epoch
# 610
# running_loss
# 0.2016446739435196
# epoch
# 611
# running_loss
# 0.18319463729858398
# epoch
# 612
# running_loss
# 0.18205974996089935
# epoch
# 613
# running_loss
# 0.23829278349876404
# epoch
# 614
# running_loss
# 0.23820728063583374
# epoch
# 615
# running_loss
# 0.22073334455490112
# epoch
# 616
# running_loss
# 0.3110364079475403
# epoch
# 617
# running_loss
# 0.37872985005378723
# epoch
# 618
# running_loss
# 0.2817526161670685
# epoch
# 619
# running_loss
# 0.18364723026752472
# epoch
# 620
# running_loss
# 0.1941695362329483
# epoch
# 621
# running_loss
# 0.2045057713985443
# epoch
# 622
# running_loss
# 0.19917583465576172
# epoch
# 623
# running_loss
# 0.1829272210597992
# epoch
# 624
# running_loss
# 0.19543959200382233
# epoch
# 625
# running_loss
# 0.2226872444152832
# epoch
# 626
# running_loss
# 0.2109905183315277
# epoch
# 627
# running_loss
# 0.22899846732616425
# epoch
# 628
# running_loss
# 0.17629866302013397
# epoch
# 629
# running_loss
# 0.1669609546661377
# epoch
# 630
# running_loss
# 0.1697637140750885
# epoch
# 631
# running_loss
# 0.2529003322124481
# epoch
# 632
# running_loss
# 0.22015276551246643
# epoch
# 633
# running_loss
# 0.18789052963256836
# epoch
# 634
# running_loss
# 0.1513596773147583
# epoch
# 635
# running_loss
# 0.1752382218837738
# epoch
# 636
# running_loss
# 0.42839065194129944
# epoch
# 637
# running_loss
# 0.3200764060020447
# epoch
# 638
# running_loss
# 0.26583945751190186
# epoch
# 639
# running_loss
# 0.2276425063610077
# epoch
# 640
# running_loss
# 0.26352939009666443
# epoch
# 641
# running_loss
# 0.28857195377349854
# epoch
# 642
# running_loss
# 0.18468362092971802
# epoch
# 643
# running_loss
# 0.19111578166484833
# epoch
# 644
# running_loss
# 0.28207290172576904
# epoch
# 645
# running_loss
# 0.31107646226882935
# epoch
# 646
# running_loss
# 0.3226938247680664
# epoch
# 647
# running_loss
# 0.2620011568069458
# epoch
# 648
# running_loss
# 0.21484509110450745
# epoch
# 649
# running_loss
# 0.23286132514476776
# epoch
# 650
# running_loss
# 0.22018836438655853
# epoch
# 651
# running_loss
# 0.2367921769618988
# epoch
# 652
# running_loss
# 0.20420624315738678
# epoch
# 653
# running_loss
# 0.2006825953722
# epoch
# 654
# running_loss
# 0.1818220317363739
# epoch
# 655
# running_loss
# 0.17445296049118042
# epoch
# 656
# running_loss
# 0.18491601943969727
# epoch
# 657
# running_loss
# 0.1775602549314499
# epoch
# 658
# running_loss
# 0.2096630334854126
# epoch
# 659
# running_loss
# 0.21516036987304688
# epoch
# 660
# running_loss
# 0.2649289667606354
# epoch
# 661
# running_loss
# 0.2444104105234146
# epoch
# 662
# running_loss
# 0.24215421080589294
# epoch
# 663
# running_loss
# 0.27612125873565674
# epoch
# 664
# running_loss
# 0.2612094283103943
# epoch
# 665
# running_loss
# 0.22787722945213318
# epoch
# 666
# running_loss
# 0.33958786725997925
# epoch
# 667
# running_loss
# 0.42415809631347656
# epoch
# 668
# running_loss
# 0.3793204128742218
# epoch
# 669
# running_loss
# 0.35715848207473755
# epoch
# 670
# running_loss
# 0.3023492693901062
# epoch
# 671
# running_loss
# 0.3579646944999695
# epoch
# 672
# running_loss
# 0.2395744025707245
# epoch
# 673
# running_loss
# 0.21925801038742065
# epoch
# 674
# running_loss
# 0.18961511552333832
# epoch
# 675
# running_loss
# 0.21707162261009216
# epoch
# 676
# running_loss
# 0.20519070327281952
# epoch
# 677
# running_loss
# 0.25200343132019043
# epoch
# 678
# running_loss
# 0.21749988198280334
# epoch
# 679
# running_loss
# 0.20845060050487518
# epoch
# 680
# running_loss
# 0.20528081059455872
# epoch
# 681
# running_loss
# 0.19364489614963531
# epoch
# 682
# running_loss
# 0.20287451148033142
# epoch
# 683
# running_loss
# 0.18307729065418243
# epoch
# 684
# running_loss
# 0.19830262660980225
# epoch
# 685
# running_loss
# 0.18821480870246887
# epoch
# 686
# running_loss
# 0.17707297205924988
# epoch
# 687
# running_loss
# 0.20423045754432678
# epoch
# 688
# running_loss
# 0.21844825148582458
# epoch
# 689
# running_loss
# 0.1930321604013443
# epoch
# 690
# running_loss
# 0.17773714661598206
# epoch
# 691
# running_loss
# 0.1819964498281479
# epoch
# 692
# running_loss
# 0.15169991552829742
# epoch
# 693
# running_loss
# 0.17878341674804688
# epoch
# 694
# running_loss
# 0.1704648733139038
# epoch
# 695
# running_loss
# 0.16511894762516022
# epoch
# 696
# running_loss
# 0.1652182787656784
# epoch
# 697
# running_loss
# 0.33624985814094543
# epoch
# 698
# running_loss
# 0.3356873095035553
# epoch
# 699
# running_loss
# 0.26421862840652466
# epoch
# 700
# running_loss
# 0.26654472947120667
# epoch
# 701
# running_loss
# 0.2419763058423996
# epoch
# 702
# running_loss
# 0.3304292559623718
# epoch
# 703
# running_loss
# 0.26838743686676025
# epoch
# 704
# running_loss
# 0.24141231179237366
# epoch
# 705
# running_loss
# 0.22681990265846252
# epoch
# 706
# running_loss
# 0.21626624464988708
# epoch
# 707
# running_loss
# 0.19689913094043732
# epoch
# 708
# running_loss
# 0.1665121614933014
# epoch
# 709
# running_loss
# 0.1919025331735611
# epoch
# 710
# running_loss
# 0.49756601452827454
# epoch
# 711
# running_loss
# 0.3868091106414795
# epoch
# 712
# running_loss
# 0.40138667821884155
# epoch
# 713
# running_loss
# 0.2691502571105957
# epoch
# 714
# running_loss
# 0.5223300457000732
# epoch
# 715
# running_loss
# 0.31609785556793213
# epoch
# 716
# running_loss
# 0.2587018311023712
# epoch
# 717
# running_loss
# 0.30214402079582214
# epoch
# 718
# running_loss
# 0.29107555747032166
# epoch
# 719
# running_loss
# 0.25424402952194214
# epoch
# 720
# running_loss
# 0.22098766267299652
# epoch
# 721
# running_loss
# 0.20864282548427582
# epoch
# 722
# running_loss
# 0.21568582952022552
# epoch
# 723
# running_loss
# 0.22751882672309875
# epoch
# 724
# running_loss
# 0.2105582356452942
# epoch
# 725
# running_loss
# 0.17804382741451263
# epoch
# 726
# running_loss
# 0.19229310750961304
# epoch
# 727
# running_loss
# 0.1885601431131363
# epoch
# 728
# running_loss
# 0.20089472830295563
# epoch
# 729
# running_loss
# 0.2000870555639267
# epoch
# 730
# running_loss
# 0.24539236724376678
# epoch
# 731
# running_loss
# 0.1976771056652069
# epoch
# 732
# running_loss
# 0.1821947991847992
# epoch
# 733
# running_loss
# 0.19519779086112976
# epoch
# 734
# running_loss
# 0.17953374981880188
# epoch
# 735
# running_loss
# 0.16951803863048553
# epoch
# 736
# running_loss
# 0.17051514983177185
# epoch
# 737
# running_loss
# 0.1943977028131485
# epoch
# 738
# running_loss
# 0.17922629415988922
# epoch
# 739
# running_loss
# 0.16683518886566162
# epoch
# 740
# running_loss
# 0.16121108829975128
# epoch
# 741
# running_loss
# 0.18309152126312256
# epoch
# 742
# running_loss
# 0.27554628252983093
# epoch
# 743
# running_loss
# 0.2233121693134308
# epoch
# 744
# running_loss
# 0.28301000595092773
# epoch
# 745
# running_loss
# 0.2678166627883911
# epoch
# 746
# running_loss
# 0.22145181894302368
# epoch
# 747
# running_loss
# 0.17395824193954468
# epoch
# 748
# running_loss
# 0.16289737820625305
# epoch
# 749
# running_loss
# 0.16336244344711304
# epoch
# 750
# running_loss
# 0.22196555137634277
# epoch
# 751
# running_loss
# 0.35361742973327637
# epoch
# 752
# running_loss
# 0.4415006637573242
# epoch
# 753
# running_loss
# 0.5632660388946533
# epoch
# 754
# running_loss
# 0.39623719453811646
# epoch
# 755
# running_loss
# 0.22137248516082764
# epoch
# 756
# running_loss
# 0.22581617534160614
# epoch
# 757
# running_loss
# 0.18926632404327393
# epoch
# 758
# running_loss
# 0.20958486199378967
# epoch
# 759
# running_loss
# 0.1707233190536499
# epoch
# 760
# running_loss
# 0.1736268699169159
# epoch
# 761
# running_loss
# 0.2137547880411148
# epoch
# 762
# running_loss
# 0.3395594656467438
# epoch
# 763
# running_loss
# 0.2866123914718628
# epoch
# 764
# running_loss
# 0.2585398256778717
# epoch
# 765
# running_loss
# 0.2506539225578308
# epoch
# 766
# running_loss
# 0.3181033730506897
# epoch
# 767
# running_loss
# 0.2760859429836273
# epoch
# 768
# running_loss
# 0.22501081228256226
# epoch
# 769
# running_loss
# 0.2002447098493576
# epoch
# 770
# running_loss
# 0.20504945516586304
# epoch
# 771
# running_loss
# 0.18269547820091248
# epoch
# 772
# running_loss
# 0.17708194255828857
# epoch
# 773
# running_loss
# 0.17185063660144806
# epoch
# 774
# running_loss
# 0.2277033030986786
# epoch
# 775
# running_loss
# 0.266185462474823
# epoch
# 776
# running_loss
# 0.21225287020206451
# epoch
# 777
# running_loss
# 0.22815072536468506
# epoch
# 778
# running_loss
# 0.2186821699142456
# epoch
# 779
# running_loss
# 0.1652500033378601
# epoch
# 780
# running_loss
# 0.1568550020456314
# epoch
# 781
# running_loss
# 0.16286450624465942
# epoch
# 782
# running_loss
# 0.33243823051452637
# epoch
# 783
# running_loss
# 0.18184274435043335
# epoch
# 784
# running_loss
# 0.20662012696266174
# epoch
# 785
# running_loss
# 0.177885040640831
# epoch
# 786
# running_loss
# 0.20973554253578186
# epoch
# 787
# running_loss
# 0.195168137550354
# epoch
# 788
# running_loss
# 0.15488429367542267
# epoch
# 789
# running_loss
# 0.23425233364105225
# epoch
# 790
# running_loss
# 0.34697192907333374
# epoch
# 791
# running_loss
# 0.24629569053649902
# epoch
# 792
# running_loss
# 0.2120034545660019
# epoch
# 793
# running_loss
# 0.23270092904567719
# epoch
# 794
# running_loss
# 0.21151122450828552
# epoch
# 795
# running_loss
# 0.16776493191719055
# epoch
# 796
# running_loss
# 0.20381206274032593
# epoch
# 797
# running_loss
# 0.1995026171207428
# epoch
# 798
# running_loss
# 0.1671372503042221
# epoch
# 799
# running_loss
# 0.17320984601974487
# epoch
# 800
# running_loss
# 0.18213221430778503
# epoch
# 801
# running_loss
# 0.16901379823684692
# epoch
# 802
# running_loss
# 0.3233419358730316
# epoch
# 803
# running_loss
# 0.2270808219909668
# epoch
# 804
# running_loss
# 0.23062396049499512
# epoch
# 805
# running_loss
# 0.19537028670310974
# epoch
# 806
# running_loss
# 0.16624069213867188
# epoch
# 807
# running_loss
# 0.15370748937129974
# epoch
# 808
# running_loss
# 0.1744682788848877
# epoch
# 809
# running_loss
# 0.17307215929031372
# epoch
# 810
# running_loss
# 0.15749558806419373
# epoch
# 811
# running_loss
# 0.1426990032196045
# epoch
# 812
# running_loss
# 0.2347089946269989
# epoch
# 813
# running_loss
# 0.23610058426856995
# epoch
# 814
# running_loss
# 0.2128109633922577
# epoch
# 815
# running_loss
# 0.1909632682800293
# epoch
# 816
# running_loss
# 0.173228457570076
# epoch
# 817
# running_loss
# 0.16530629992485046
# epoch
# 818
# running_loss
# 0.3135169744491577
# epoch
# 819
# running_loss
# 0.19242800772190094
# epoch
# 820
# running_loss
# 0.16929571330547333
# epoch
# 821
# running_loss
# 0.14370840787887573
# epoch
# 822
# running_loss
# 0.18553569912910461
# epoch
# 823
# running_loss
# 0.19623634219169617
# epoch
# 824
# running_loss
# 0.20879793167114258
# epoch
# 825
# running_loss
# 0.18822041153907776
# epoch
# 826
# running_loss
# 0.2804153561592102
# epoch
# 827
# running_loss
# 0.2542757987976074
# epoch
# 828
# running_loss
# 0.1741325706243515
# epoch
# 829
# running_loss
# 0.203740656375885
# epoch
# 830
# running_loss
# 0.2353612184524536
# epoch
# 831
# running_loss
# 0.1964944303035736
# epoch
# 832
# running_loss
# 0.15991085767745972
# epoch
# 833
# running_loss
# 0.16198287904262543
# epoch
# 834
# running_loss
# 0.14280635118484497
# epoch
# 835
# running_loss
# 0.16555851697921753
# epoch
# 836
# running_loss
# 0.18848733603954315
# epoch
# 837
# running_loss
# 0.1981072872877121
# epoch
# 838
# running_loss
# 0.16301552951335907
# epoch
# 839
# running_loss
# 0.179445281624794
# epoch
# 840
# running_loss
# 0.15849877893924713
# epoch
# 841
# running_loss
# 0.12963300943374634
# epoch
# 842
# running_loss
# 0.21067172288894653
# epoch
# 843
# running_loss
# 0.1550895869731903
# epoch
# 844
# running_loss
# 0.36849039793014526
# epoch
# 845
# running_loss
# 0.2909649908542633
# epoch
# 846
# running_loss
# 0.3319211006164551
# epoch
# 847
# running_loss
# 0.2544037401676178
# epoch
# 848
# running_loss
# 0.22778935730457306
# epoch
# 849
# running_loss
# 0.186239093542099
# epoch
# 850
# running_loss
# 0.2143653780221939
# epoch
# 851
# running_loss
# 0.15621735155582428
# epoch
# 852
# running_loss
# 0.5356931686401367
# epoch
# 853
# running_loss
# 0.3147774636745453
# epoch
# 854
# running_loss
# 0.39231717586517334
# epoch
# 855
# running_loss
# 0.3783530592918396
# epoch
# 856
# running_loss
# 0.36043602228164673
# epoch
# 857
# running_loss
# 0.31984061002731323
# epoch
# 858
# running_loss
# 0.27572891116142273
# epoch
# 859
# running_loss
# 0.23498719930648804
# epoch
# 860
# running_loss
# 0.23669685423374176
# epoch
# 861
# running_loss
# 0.22016187012195587
# epoch
# 862
# running_loss
# 0.23807939887046814
# epoch
# 863
# running_loss
# 0.1985742598772049
# epoch
# 864
# running_loss
# 0.21988293528556824
# epoch
# 865
# running_loss
# 0.22319206595420837
# epoch
# 866
# running_loss
# 0.26610541343688965
# epoch
# 867
# running_loss
# 0.20078089833259583
# epoch
# 868
# running_loss
# 0.20646299421787262
# epoch
# 869
# running_loss
# 0.22098645567893982
# epoch
# 870
# running_loss
# 0.19782687723636627
# epoch
# 871
# running_loss
# 0.2105407565832138
# epoch
# 872
# running_loss
# 0.21442189812660217
# epoch
# 873
# running_loss
# 0.22394654154777527
# epoch
# 874
# running_loss
# 0.22620534896850586
# epoch
# 875
# running_loss
# 0.20926012098789215
# epoch
# 876
# running_loss
# 0.2130870670080185
# epoch
# 877
# running_loss
# 0.20581844449043274
# epoch
# 878
# running_loss
# 0.2932066321372986
# epoch
# 879
# running_loss
# 0.2933075428009033
# epoch
# 880
# running_loss
# 0.24419942498207092
# epoch
# 881
# running_loss
# 0.25544053316116333
# epoch
# 882
# running_loss
# 0.28377360105514526
# epoch
# 883
# running_loss
# 0.22754189372062683
# epoch
# 884
# running_loss
# 0.23786628246307373
# epoch
# 885
# running_loss
# 0.18111388385295868
# epoch
# 886
# running_loss
# 0.2009722888469696
# epoch
# 887
# running_loss
# 0.25080665946006775
# epoch
# 888
# running_loss
# 0.19940094649791718
# epoch
# 889
# running_loss
# 0.18080222606658936
# epoch
# 890
# running_loss
# 0.20895707607269287
# epoch
# 891
# running_loss
# 0.1675063967704773
# epoch
# 892
# running_loss
# 0.20644426345825195
# epoch
# 893
# running_loss
# 0.6294198036193848
# epoch
# 894
# running_loss
# 0.56859290599823
# epoch
# 895
# running_loss
# 0.392699658870697
# epoch
# 896
# running_loss
# 0.2976580858230591
# epoch
# 897
# running_loss
# 0.26181715726852417
# epoch
# 898
# running_loss
# 0.2537855803966522
# epoch
# 899
# running_loss
# 0.2422577440738678
# epoch
# 900
# running_loss
# 0.22098928689956665
# epoch
# 901
# running_loss
# 0.209458589553833
# epoch
# 902
# running_loss
# 0.23376256227493286
# epoch
# 903
# running_loss
# 0.21041110157966614
# epoch
# 904
# running_loss
# 0.22412343323230743
# epoch
# 905
# running_loss
# 0.19506889581680298
# epoch
# 906
# running_loss
# 0.23912301659584045
# epoch
# 907
# running_loss
# 0.3695441782474518
# epoch
# 908
# running_loss
# 0.2540803551673889
# epoch
# 909
# running_loss
# 0.2179565280675888
# epoch
# 910
# running_loss
# 0.2040812224149704
# epoch
# 911
# running_loss
# 0.18814527988433838
# epoch
# 912
# running_loss
# 0.209025576710701
# epoch
# 913
# running_loss
# 0.2239900827407837
# epoch
# 914
# running_loss
# 0.2236866056919098
# epoch
# 915
# running_loss
# 0.20833933353424072
# epoch
# 916
# running_loss
# 0.1856248378753662
# epoch
# 917
# running_loss
# 0.2017238587141037
# epoch
# 918
# running_loss
# 0.20310118794441223
# epoch
# 919
# running_loss
# 0.18617483973503113
# epoch
# 920
# running_loss
# 0.20793819427490234
# epoch
# 921
# running_loss
# 0.18628433346748352
# epoch
# 922
# running_loss
# 0.30814671516418457
# epoch
# 923
# running_loss
# 0.2557468116283417
# epoch
# 924
# running_loss
# 0.20531927049160004
# epoch
# 925
# running_loss
# 0.19536657631397247
# epoch
# 926
# running_loss
# 0.18761055171489716
# epoch
# 927
# running_loss
# 0.1671573519706726
# epoch
# 928
# running_loss
# 0.20029133558273315
# epoch
# 929
# running_loss
# 0.16588732600212097
# epoch
# 930
# running_loss
# 0.31325024366378784
# epoch
# 931
# running_loss
# 0.23631080985069275
# epoch
# 932
# running_loss
# 0.20421715080738068
# epoch
# 933
# running_loss
# 1.104500651359558
# epoch
# 934
# running_loss
# 0.9410194158554077
# epoch
# 935
# running_loss
# 1.0557332038879395
# epoch
# 936
# running_loss
# 0.589767336845398
# epoch
# 937
# running_loss
# 0.44329923391342163
# epoch
# 938
# running_loss
# 0.33656221628189087
# epoch
# 939
# running_loss
# 0.33462706208229065
# epoch
# 940
# running_loss
# 0.28635892271995544
# epoch
# 941
# running_loss
# 0.23512426018714905
# epoch
# 942
# running_loss
# 0.24668388068675995
# epoch
# 943
# running_loss
# 0.24310234189033508
# epoch
# 944
# running_loss
# 0.26195478439331055
# epoch
# 945
# running_loss
# 0.25160133838653564
# epoch
# 946
# running_loss
# 0.24155372381210327
# epoch
# 947
# running_loss
# 0.22295458614826202
# epoch
# 948
# running_loss
# 0.22141213715076447
# epoch
# 949
# running_loss
# 0.20492151379585266
# epoch
# 950
# running_loss
# 0.2370414435863495
# epoch
# 951
# running_loss
# 0.22837117314338684
# epoch
# 952
# running_loss
# 0.22391638159751892
# epoch
# 953
# running_loss
# 0.2003760188817978
# epoch
# 954
# running_loss
# 0.2138093262910843
# epoch
# 955
# running_loss
# 0.21508431434631348
# epoch
# 956
# running_loss
# 0.20196717977523804
# epoch
# 957
# running_loss
# 0.2283092886209488
# epoch
# 958
# running_loss
# 0.21452972292900085
# epoch
# 959
# running_loss
# 0.22437793016433716
# epoch
# 960
# running_loss
# 0.18378807604312897
# epoch
# 961
# running_loss
# 1.3973934650421143
# epoch
# 962
# running_loss
# 0.7860597968101501
# epoch
# 963
# running_loss
# 0.7620269060134888
# epoch
# 964
# running_loss
# 0.6599092483520508
# epoch
# 965
# running_loss
# 0.5526609420776367
# epoch
# 966
# running_loss
# 0.5128872394561768
# epoch
# 967
# running_loss
# 0.44702744483947754
# epoch
# 968
# running_loss
# 0.4177456498146057
# epoch
# 969
# running_loss
# 0.4146445393562317
# epoch
# 970
# running_loss
# 0.38886401057243347
# epoch
# 971
# running_loss
# 0.27774906158447266
# epoch
# 972
# running_loss
# 0.2385537177324295
# epoch
# 973
# running_loss
# 0.24745839834213257
# epoch
# 974
# running_loss
# 0.23025497794151306
# epoch
# 975
# running_loss
# 0.21443301439285278
# epoch
# 976
# running_loss
# 0.22255241870880127
# epoch
# 977
# running_loss
# 0.1944245994091034
# epoch
# 978
# running_loss
# 0.2137477695941925
# epoch
# 979
# running_loss
# 0.22386662662029266
# epoch
# 980
# running_loss
# 0.2247304469347
# epoch
# 981
# running_loss
# 0.19703751802444458
# epoch
# 982
# running_loss
# 0.1926252543926239
# epoch
# 983
# running_loss
# 0.20366092026233673
# epoch
# 984
# running_loss
# 0.21018505096435547
# epoch
# 985
# running_loss
# 0.19039547443389893
# epoch
# 986
# running_loss
# 0.19526854157447815
# epoch
# 987
# running_loss
# 0.19650596380233765
# epoch
# 988
# running_loss
# 0.2067706286907196
# epoch
# 989
# running_loss
# 0.19253990054130554
# epoch
# 990
# running_loss
# 0.2017040103673935
# epoch
# 991
# running_loss
# 0.1971282660961151
# epoch
# 992
# running_loss
# 0.20998091995716095
# epoch
# 993
# running_loss
# 0.1894402951002121
# epoch
# 994
# running_loss
# 0.20172539353370667
# epoch
# 995
# running_loss
# 0.19077475368976593
# epoch
# 996
# running_loss
# 0.19858863949775696
# epoch
# 997
# running_loss
# 0.20612338185310364
# epoch
# 998
# running_loss
# 0.2057880163192749
# epoch
# 999
# running_loss
# 0.19703887403011322
# epoch
# 1000
# running_loss
# 0.19056160748004913
# epoch
# 1001
# running_loss
# 0.1821255087852478
# epoch
# 1002
# running_loss
# 0.17595171928405762
# epoch
# 1003
# running_loss
# 0.1732923686504364
# epoch
# 1004
# running_loss
# 0.17090441286563873
# epoch
# 1005
# running_loss
# 0.19292454421520233
# epoch
# 1006
# running_loss
# 0.17451833188533783
# epoch
# 1007
# running_loss
# 0.17020100355148315
# epoch
# 1008
# running_loss
# 0.1847246289253235
# epoch
# 1009
# running_loss
# 0.1707037091255188
# epoch
# 1010
# running_loss
# 0.18411196768283844
# epoch
# 1011
# running_loss
# 0.16588018834590912
# epoch
# 1012
# running_loss
# 0.17971380054950714
# epoch
# 1013
# running_loss
# 0.17782217264175415
# epoch
# 1014
# running_loss
# 0.17454668879508972
# epoch
# 1015
# running_loss
# 0.1825115978717804
# epoch
# 1016
# running_loss
# 0.17591023445129395
# epoch
# 1017
# running_loss
# 0.1764979064464569
# epoch
# 1018
# running_loss
# 0.17047491669654846
# epoch
# 1019
# running_loss
# 0.1797366589307785
# epoch
# 1020
# running_loss
# 0.1768149584531784
# epoch
# 1021
# running_loss
# 0.16062845289707184
# epoch
# 1022
# running_loss
# 0.16412660479545593
# epoch
# 1023
# running_loss
# 0.17249251902103424
# epoch
# 1024
# running_loss
# 0.17397743463516235
# epoch
# 1025
# running_loss
# 0.17903834581375122
# epoch
# 1026
# running_loss
# 0.1621909886598587
# epoch
# 1027
# running_loss
# 0.17291894555091858
# epoch
# 1028
# running_loss
# 0.164982408285141
# epoch
# 1029
# running_loss
# 0.162017822265625
# epoch
# 1030
# running_loss
# 0.18181563913822174
# epoch
# 1031
# running_loss
# 0.17612294852733612
# epoch
# 1032
# running_loss
# 0.1728293001651764
# epoch
# 1033
# running_loss
# 0.15343917906284332
# epoch
# 1034
# running_loss
# 0.16920360922813416
# epoch
# 1035
# running_loss
# 0.16895481944084167
# epoch
# 1036
# running_loss
# 0.18610186874866486
# epoch
# 1037
# running_loss
# 0.15717537701129913
# epoch
# 1038
# running_loss
# 0.1625390648841858
# epoch
# 1039
# running_loss
# 0.164936363697052
# epoch
# 1040
# running_loss
# 0.15599612891674042
# epoch
# 1041
# running_loss
# 0.1684584617614746
# epoch
# 1042
# running_loss
# 0.16337554156780243
# epoch
# 1043
# running_loss
# 0.16668042540550232
# epoch
# 1044
# running_loss
# 0.18327604234218597
# epoch
# 1045
# running_loss
# 0.1614476889371872
# epoch
# 1046
# running_loss
# 0.1539425253868103
# epoch
# 1047
# running_loss
# 0.1663094162940979
# epoch
# 1048
# running_loss
# 0.15787473320960999
# epoch
# 1049
# running_loss
# 0.17179250717163086
# epoch
# 1050
# running_loss
# 0.16141466796398163
# epoch
# 1051
# running_loss
# 0.15205435454845428
# epoch
# 1052
# running_loss
# 0.16063115000724792
# epoch
# 1053
# running_loss
# 0.17352384328842163
# epoch
# 1054
# running_loss
# 0.14719827473163605
# epoch
# 1055
# running_loss
# 0.15906217694282532
# epoch
# 1056
# running_loss
# 0.15452346205711365
# epoch
# 1057
# running_loss
# 0.15663816034793854
# epoch
# 1058
# running_loss
# 0.15764281153678894
# epoch
# 1059
# running_loss
# 0.16765454411506653
# epoch
# 1060
# running_loss
# 0.15499694645404816
# epoch
# 1061
# running_loss
# 0.1614910215139389
# epoch
# 1062
# running_loss
# 0.15596941113471985
# epoch
# 1063
# running_loss
# 0.1503342092037201
# epoch
# 1064
# running_loss
# 0.16404545307159424
# epoch
# 1065
# running_loss
# 0.15788191556930542
# epoch
# 1066
# running_loss
# 0.15961626172065735
# epoch
# 1067
# running_loss
# 0.16190901398658752
# epoch
# 1068
# running_loss
# 0.15312641859054565
# epoch
# 1069
# running_loss
# 0.16011500358581543
# epoch
# 1070
# running_loss
# 0.16325238347053528
# epoch
# 1071
# running_loss
# 0.14343366026878357
# epoch
# 1072
# running_loss
# 0.16068822145462036
# epoch
# 1073
# running_loss
# 0.15469789505004883
# epoch
# 1074
# running_loss
# 0.15149559080600739
# epoch
# 1075
# running_loss
# 0.14959120750427246
# epoch
# 1076
# running_loss
# 0.15326304733753204
# epoch
# 1077
# running_loss
# 0.14249786734580994
# epoch
# 1078
# running_loss
# 0.15440934896469116
# epoch
# 1079
# running_loss
# 0.15293553471565247
# epoch
# 1080
# running_loss
# 0.1530725359916687
# epoch
# 1081
# running_loss
# 0.14264284074306488
# epoch
# 1082
# running_loss
# 0.14955967664718628
# epoch
# 1083
# running_loss
# 0.15558654069900513
# epoch
# 1084
# running_loss
# 0.15480054914951324
# epoch
# 1085
# running_loss
# 0.14483600854873657
# epoch
# 1086
# running_loss
# 0.14399580657482147
# epoch
# 1087
# running_loss
# 0.13432875275611877
# epoch
# 1088
# running_loss
# 0.1518091857433319
# epoch
# 1089
# running_loss
# 0.15396834909915924
# epoch
# 1090
# running_loss
# 0.14692184329032898
# epoch
# 1091
# running_loss
# 0.1422753632068634
# epoch
# 1092
# running_loss
# 0.14700400829315186
# epoch
# 1093
# running_loss
# 0.14390069246292114
# epoch
# 1094
# running_loss
# 0.14709195494651794
# epoch
# 1095
# running_loss
# 0.14571605622768402
# epoch
# 1096
# running_loss
# 0.15337887406349182
# epoch
# 1097
# running_loss
# 0.1478843092918396
# epoch
# 1098
# running_loss
# 0.1427745372056961
# epoch
# 1099
# running_loss
# 0.14197412133216858
# epoch
# 1100
# running_loss
# 0.13368329405784607
# epoch
# 1101
# running_loss
# 0.13813236355781555
# epoch
# 1102
# running_loss
# 0.14156147837638855
# epoch
# 1103
# running_loss
# 0.1379459947347641
# epoch
# 1104
# running_loss
# 0.1395423412322998
# epoch
# 1105
# running_loss
# 0.1322869062423706
# epoch
# 1106
# running_loss
# 0.1495540887117386
# epoch
# 1107
# running_loss
# 0.13781198859214783
# epoch
# 1108
# running_loss
# 0.13732117414474487
# epoch
# 1109
# running_loss
# 0.13827912509441376
# epoch
# 1110
# running_loss
# 0.13601882755756378
# epoch
# 1111
# running_loss
# 0.14270995557308197
# epoch
# 1112
# running_loss
# 0.14097870886325836
# epoch
# 1113
# running_loss
# 0.138604998588562
# epoch
# 1114
# running_loss
# 0.145370751619339
# epoch
# 1115
# running_loss
# 0.12930892407894135
# epoch
# 1116
# running_loss
# 0.1296367645263672
# epoch
# 1117
# running_loss
# 0.12064197659492493
# epoch
# 1118
# running_loss
# 0.14024418592453003
# epoch
# 1119
# running_loss
# 0.12378042936325073
# epoch
# 1120
# running_loss
# 0.13124170899391174
# epoch
# 1121
# running_loss
# 0.18734018504619598
# epoch
# 1122
# running_loss
# 0.1407746523618698
# epoch
# 1123
# running_loss
# 0.13942377269268036
# epoch
# 1124
# running_loss
# 0.1227751299738884
# epoch
# 1125
# running_loss
# 0.12588724493980408
# epoch
# 1126
# running_loss
# 0.13061454892158508
# epoch
# ...
# epoch
# 7651
# running_loss
# 0.0012438786216080189
# epoch
# 7652
# running_loss
# 0.001595099689438939
# epoch
# 7653
# running_loss
# 0.0014130168128758669
# epoch
# 7654
# running_loss
# 0.001762462081387639
# epoch
# 7655
# running_loss
# 0.0028363142628222704
# epoch
# 7656
# running_loss
# 0.003776762867346406
# epoch
# 7657
# running_loss
# 0.0023131733760237694
# epoch
# 7658
# running_loss
# 0.00137991807423532
# epoch
# 7659
# running_loss
# 0.0014445772394537926
# epoch
# 7660
# running_loss
# 0.0018216485623270273
# epoch
# 7661
# running_loss
# 0.0017811309080570936
# epoch
# 7662
# running_loss
# 0.0020528489258140326
# epoch
# 7663
# running_loss
# 0.0023425640538334846
# epoch
# 7664
# running_loss
# 0.0014580029528588057
# epoch
# 7665
# running_loss
# 0.0012922266032546759
# epoch
# 7666
# running_loss
# 0.0012609148398041725
# epoch
# 7667
# running_loss
# 0.0024489127099514008
# epoch
# 7668
# running_loss
# 0.004008992575109005
# epoch
# 7669
# running_loss
# 0.0017475318163633347
# epoch
# 7670
# running_loss
# 0.0015403588768094778
# epoch
# 7671
# running_loss
# 0.0023619227577000856
# epoch
# 7672
# running_loss
# 0.0013090727152302861
# epoch
# 7673
# running_loss
# 0.0016865459037944674
# epoch
# 7674
# running_loss
# 0.001364988973364234
# epoch
# 7675
# running_loss
# 0.0013112712185829878
# epoch
# 7676
# running_loss
# 0.00160425272770226
# epoch
# 7677
# running_loss
# 0.0013100517680868506
# epoch
# 7678
# running_loss
# 0.0015240416396409273
# epoch
# 7679
# running_loss
# 0.001341582858003676
# epoch
# 7680
# running_loss
# 0.0012601843336597085
# epoch
# 7681
# running_loss
# 0.0012290994636714458
# epoch
# 7682
# running_loss
# 0.0012003429001197219
# epoch
# 7683
# running_loss
# 0.0013661462580785155
# epoch
# 7684
# running_loss
# 0.0013549922732636333
# epoch
# 7685
# running_loss
# 0.0014856205089017749
# epoch
# 7686
# running_loss
# 0.0014468396548181772
# epoch
# 7687
# running_loss
# 0.00153478910215199
# epoch
# 7688
# running_loss
# 0.0012587447417899966
# epoch
# 7689
# running_loss
# 0.0014512833440676332
# epoch
# 7690
# running_loss
# 0.001779485261067748
# epoch
# 7691
# running_loss
# 0.002423111582174897
# epoch
# 7692
# running_loss
# 0.0014100557891651988
# epoch
# 7693
# running_loss
# 0.0014500272227451205
# epoch
# 7694
# running_loss
# 0.0014991264324635267
# epoch
# 7695
# running_loss
# 0.0018494611140340567
# epoch
# 7696
# running_loss
# 0.0014256932772696018
# epoch
# 7697
# running_loss
# 0.001412565354257822
# epoch
# 7698
# running_loss
# 0.0013115077745169401
# epoch
# 7699
# running_loss
# 0.0012295761844143271
# epoch
# 7700
# running_loss
# 0.0015680151991546154
# epoch
# 7701
# running_loss
# 0.0019803200848400593
# epoch
# 7702
# running_loss
# 0.0015387149760499597
# epoch
# 7703
# running_loss
# 0.0012806837912648916
# epoch
# 7704
# running_loss
# 0.001276473980396986
# epoch
# 7705
# running_loss
# 0.0012068371288478374
# epoch
# 7706
# running_loss
# 0.0013285656459629536
# epoch
# 7707
# running_loss
# 0.001404465176165104
# epoch
# 7708
# running_loss
# 0.0021251575089991093
# epoch
# 7709
# running_loss
# 0.0014558688271790743
# epoch
# 7710
# running_loss
# 0.0020345249213278294
# epoch
# 7711
# running_loss
# 0.001315957517363131
# epoch
# 7712
# running_loss
# 0.0014550045598298311
# epoch
# 7713
# running_loss
# 0.0015729775186628103
# epoch
# 7714
# running_loss
# 0.0024615286383777857
# epoch
# 7715
# running_loss
# 0.0013279657578095794
# epoch
# 7716
# running_loss
# 0.0015858642291277647
# epoch
# 7717
# running_loss
# 0.0015489393845200539
# epoch
# 7718
# running_loss
# 0.001353379338979721
# epoch
# 7719
# running_loss
# 0.0012677747290581465
# epoch
# 7720
# running_loss
# 0.001347517711110413
# epoch
# 7721
# running_loss
# 0.0014266258804127574
# epoch
# 7722
# running_loss
# 0.0014730992261320353
# epoch
# 7723
# running_loss
# 0.00146506039891392
# epoch
# 7724
# running_loss
# 0.0013582793762907386
# epoch
# 7725
# running_loss
# 0.0013453593710437417
# epoch
# 7726
# running_loss
# 0.0010577633511275053
# epoch
# 7727
# running_loss
# 0.0016129732830449939
# epoch
# 7728
# running_loss
# 0.0014400266809388995
# epoch
# 7729
# running_loss
# 0.0016082022339105606
# epoch
# 7730
# running_loss
# 0.0022358717396855354
# epoch
# 7731
# running_loss
# 0.001543955528177321
# epoch
# 7732
# running_loss
# 0.0014146323082968593
# epoch
# 7733
# running_loss
# 0.0017236685380339622
# epoch
# 7734
# running_loss
# 0.0015122864861041307
# epoch
# 7735
# running_loss
# 0.0012135037686675787
# epoch
# 7736
# running_loss
# 0.00133196369279176
# epoch
# 7737
# running_loss
# 0.0020230032969266176
# epoch
# 7738
# running_loss
# 0.004073282703757286
# epoch
# 7739
# running_loss
# 0.00290145562030375
# epoch
# 7740
# running_loss
# 0.0019914964213967323
# epoch
# 7741
# running_loss
# 0.001363535295240581
# epoch
# 7742
# running_loss
# 0.0018671248108148575
# epoch
# 7743
# running_loss
# 0.0018332134932279587
# epoch
# 7744
# running_loss
# 0.001739335129968822
# epoch
# 7745
# running_loss
# 0.0017353076254948974
# epoch
# 7746
# running_loss
# 0.001365366391837597
# epoch
# 7747
# running_loss
# 0.0013811022508889437
# epoch
# 7748
# running_loss
# 0.0011312866117805243
# epoch
# 7749
# running_loss
# 0.001534937764517963
# epoch
# 7750
# running_loss
# 0.0012252836022526026
# epoch
# 7751
# running_loss
# 0.0012372651835903525
# epoch
# 7752
# running_loss
# 0.001487893401645124
# epoch
# 7753
# running_loss
# 0.0016035239677876234
# epoch
# 7754
# running_loss
# 0.0014108822215348482
# epoch
# 7755
# running_loss
# 0.0018147345399484038
# epoch
# 7756
# running_loss
# 0.0015294518088921905
# epoch
# 7757
# running_loss
# 0.0016667734598740935
# epoch
# 7758
# running_loss
# 0.0014352506259456277
# epoch
# 7759
# running_loss
# 0.0013013050192967057
# epoch
# 7760
# running_loss
# 0.0014049751916900277
# epoch
# 7761
# running_loss
# 0.0014416694175451994
# epoch
# 7762
# running_loss
# 0.0014124964363873005
# epoch
# 7763
# running_loss
# 0.0015817225212231278
# epoch
# 7764
# running_loss
# 0.001529891975224018
# epoch
# 7765
# running_loss
# 0.0013044156366959214
# epoch
# 7766
# running_loss
# 0.0016465854132547975
# epoch
# 7767
# running_loss
# 0.0012149636168032885
# epoch
# 7768
# running_loss
# 0.0011696615256369114
# epoch
# 7769
# running_loss
# 0.0011915868381038308
# epoch
# 7770
# running_loss
# 0.0018322609830647707
# epoch
# 7771
# running_loss
# 0.0013211295008659363
# epoch
# 7772
# running_loss
# 0.0016201753169298172
# epoch
# 7773
# running_loss
# 0.001227973378263414
# epoch
# 7774
# running_loss
# 0.0013743952149525285
# epoch
# 7775
# running_loss
# 0.0015182276256382465
# epoch
# 7776
# running_loss
# 0.001355905900709331
# epoch
# 7777
# running_loss
# 0.0014882583636790514
# epoch
# 7778
# running_loss
# 0.0019138671923428774
# epoch
# 7779
# running_loss
# 0.0015834638616070151
# epoch
# 7780
# running_loss
# 0.0016307872720062733
# epoch
# 7781
# running_loss
# 0.0013044755905866623
# epoch
# 7782
# running_loss
# 0.0017934702336788177
# epoch
# 7783
# running_loss
# 0.0018831458874046803
# epoch
# 7784
# running_loss
# 0.0017943722195923328
# epoch
# 7785
# running_loss
# 0.001778246951289475
# epoch
# 7786
# running_loss
# 0.0011550802737474442
# epoch
# 7787
# running_loss
# 0.001791094895452261
# epoch
# 7788
# running_loss
# 0.0014543671859428287
# epoch
# 7789
# running_loss
# 0.0011868843575939536
# epoch
# 7790
# running_loss
# 0.0011692582629621029
# epoch
# 7791
# running_loss
# 0.0013146543642506003
# epoch
# 7792
# running_loss
# 0.0019411616958677769
# epoch
# 7793
# running_loss
# 0.0024757911451160908
# epoch
# 7794
# running_loss
# 0.0034472490660846233
# epoch
# 7795
# running_loss
# 0.001356166903860867
# epoch
# 7796
# running_loss
# 0.0018470050999894738
# epoch
# 7797
# running_loss
# 0.001391074270941317
# epoch
# 7798
# running_loss
# 0.002414332702755928
# epoch
# 7799
# running_loss
# 0.04131784290075302
# epoch
# 7800
# running_loss
# 0.09813341498374939
# epoch
# 7801
# running_loss
# 0.011412262916564941
# epoch
# 7802
# running_loss
# 0.00433369493111968
# epoch
# 7803
# running_loss
# 0.0063322908245027065
# epoch
# 7804
# running_loss
# 0.0030372689943760633
# epoch
# 7805
# running_loss
# 0.0022935715969651937
# epoch
# 7806
# running_loss
# 0.0012860145652666688
# epoch
# 7807
# running_loss
# 0.0013181627728044987
# epoch
# 7808
# running_loss
# 0.0015491145895794034
# epoch
# 7809
# running_loss
# 0.0014594706008210778
# epoch
# 7810
# running_loss
# 0.0015175100415945053
# epoch
# 7811
# running_loss
# 0.002455359324812889
# epoch
# 7812
# running_loss
# 0.0018954739207401872
# epoch
# 7813
# running_loss
# 0.001352287596091628
# epoch
# 7814
# running_loss
# 0.0013794192345812917
# epoch
# 7815
# running_loss
# 0.001512128859758377
# epoch
# 7816
# running_loss
# 0.0015048531349748373
# epoch
# 7817
# running_loss
# 0.0013235390651971102
# epoch
# 7818
# running_loss
# 0.0012730627786368132
# epoch
# 7819
# running_loss
# 0.0012079633306711912
# epoch
# 7820
# running_loss
# 0.0017564668087288737
# epoch
# 7821
# running_loss
# 0.0024120609741657972
# epoch
# 7822
# running_loss
# 0.0014862874522805214
# epoch
# 7823
# running_loss
# 0.0013371480163186789
# epoch
# 7824
# running_loss
# 0.0017309896647930145
# epoch
# 7825
# running_loss
# 0.0013110684230923653
# epoch
# 7826
# running_loss
# 0.001162674743682146
# epoch
# 7827
# running_loss
# 0.001423644833266735
# epoch
# 7828
# running_loss
# 0.0016786149935796857
# epoch
# 7829
# running_loss
# 0.0014125322923064232
# epoch
# 7830
# running_loss
# 0.0013728482881560922
# epoch
# 7831
# running_loss
# 0.00135614478494972
# epoch
# 7832
# running_loss
# 0.0012357214000076056
# epoch
# 7833
# running_loss
# 0.0014991380739957094
# epoch
# 7834
# running_loss
# 0.0011643519392237067
# epoch
# 7835
# running_loss
# 0.001286428770981729
# epoch
# 7836
# running_loss
# 0.0011506435694172978
# epoch
# 7837
# running_loss
# 0.0012321356916800141
# epoch
# 7838
# running_loss
# 0.0014804113889113069
# epoch
# 7839
# running_loss
# 0.0013518882915377617
# epoch
# 7840
# running_loss
# 0.001410683966241777
# epoch
# 7841
# running_loss
# 0.0014794685412198305
# epoch
# 7842
# running_loss
# 0.001394203514792025
# epoch
# 7843
# running_loss
# 0.0013590500457212329
# epoch
# 7844
# running_loss
# 0.0013781307497993112
# epoch
# 7845
# running_loss
# 0.0012326407013460994
# epoch
# 7846
# running_loss
# 0.0012213638983666897
# epoch
# 7847
# running_loss
# 0.0011370648862794042
# epoch
# 7848
# running_loss
# 0.001258533215150237
# epoch
# 7849
# running_loss
# 0.001337914727628231
# epoch
# 7850
# running_loss
# 0.0015221323119476438
# epoch
# 7851
# running_loss
# 0.0010989154689013958
# epoch
# 7852
# running_loss
# 0.001405502436682582
# epoch
# 7853
# running_loss
# 0.0011906824074685574
# epoch
# 7854
# running_loss
# 0.0013194656930863857
# epoch
# 7855
# running_loss
# 0.0018346465658396482
# epoch
# 7856
# running_loss
# 0.0015144051285460591
# epoch
# 7857
# running_loss
# 0.0015045411419123411
# epoch
# 7858
# running_loss
# 0.0015940204029902816
# epoch
# 7859
# running_loss
# 0.0015056395204737782
# epoch
# 7860
# running_loss
# 0.0015123960329219699
# epoch
# 7861
# running_loss
# 0.0011481267865747213
# epoch
# 7862
# running_loss
# 0.0014661232708021998
# epoch
# 7863
# running_loss
# 0.0014073556521907449
# epoch
# 7864
# running_loss
# 0.0012382548302412033
# epoch
# 7865
# running_loss
# 0.0013382937759160995
# epoch
# 7866
# running_loss
# 0.0015959787415340543
# epoch
# 7867
# running_loss
# 0.0014966980088502169
# epoch
# 7868
# running_loss
# 0.0014260319294407964
# epoch
# 7869
# running_loss
# 0.0013060662895441055
# epoch
# 7870
# running_loss
# 0.001576114445924759
# epoch
# 7871
# running_loss
# 0.0014666842762380838
# epoch
# 7872
# running_loss
# 0.001216203672811389
# epoch
# 7873
# running_loss
# 0.0012011914514005184
# epoch
# 7874
# running_loss
# 0.0012158813187852502
# epoch
# 7875
# running_loss
# 0.0013462648494169116
# epoch
# 7876
# running_loss
# 0.0013722926378250122
# epoch
# 7877
# running_loss
# 0.0013382333563640714
# epoch
# 7878
# running_loss
# 0.0016207138542085886
# epoch
# 7879
# running_loss
# 0.0012645376846194267
# epoch
# 7880
# running_loss
# 0.0015186306554824114
# epoch
# 7881
# running_loss
# 0.0013182919938117266
# epoch
# 7882
# running_loss
# 0.00136353331618011
# epoch
# 7883
# running_loss
# 0.0013243091525509953
# epoch
# 7884
# running_loss
# 0.0012792869238182902
# epoch
# 7885
# running_loss
# 0.001866369042545557
# epoch
# 7886
# running_loss
# 0.0013547459384426475
# epoch
# 7887
# running_loss
# 0.0014040879905223846
# epoch
# 7888
# running_loss
# 0.001686879782937467
# epoch
# 7889
# running_loss
# 0.0018895218381658196
# epoch
# 7890
# running_loss
# 0.001953908009454608
# epoch
# 7891
# running_loss
# 0.0013256085803732276
# epoch
# 7892
# running_loss
# 0.0011644624173641205
# epoch
# 7893
# running_loss
# 0.0012615264859050512
# epoch
# 7894
# running_loss
# 0.003002426354214549
# epoch
# 7895
# running_loss
# 0.0014294541906565428
# epoch
# 7896
# running_loss
# 0.0014597972622141242
# epoch
# 7897
# running_loss
# 0.0013667176244780421
# epoch
# 7898
# running_loss
# 0.002618295606225729
# epoch
# 7899
# running_loss
# 0.0015848997281864285
# epoch
# 7900
# running_loss
# 0.00151693110819906
# epoch
# 7901
# running_loss
# 0.00268792686983943
# epoch
# 7902
# running_loss
# 0.0010681822896003723
# epoch
# 7903
# running_loss
# 0.004386072512716055
# epoch
# 7904
# running_loss
# 0.0031517643947154284
# epoch
# 7905
# running_loss
# 0.03409401699900627
# epoch
# 7906
# running_loss
# 0.009544511325657368
# epoch
# 7907
# running_loss
# 0.0020259611774235964
# epoch
# 7908
# running_loss
# 0.00891441572457552
# epoch
# 7909
# running_loss
# 0.0013409651583060622
# epoch
# 7910
# running_loss
# 0.0018019663402810693
# epoch
# 7911
# running_loss
# 0.0034426122438162565
# epoch
# 7912
# running_loss
# 0.003572349203750491
# epoch
# 7913
# running_loss
# 0.001934184692800045
# epoch
# 7914
# running_loss
# 0.002469539176672697
# epoch
# 7915
# running_loss
# 0.0019098747288808227
# epoch
# 7916
# running_loss
# 0.0011486168950796127
# epoch
# 7917
# running_loss
# 0.0012873803498223424
# epoch
# 7918
# running_loss
# 0.0015200285706669092
# epoch
# 7919
# running_loss
# 0.0015240204520523548
# epoch
# 7920
# running_loss
# 0.001403480302542448
# epoch
# 7921
# running_loss
# 0.0012923919130116701
# epoch
# 7922
# running_loss
# 0.0009889642242342234
# epoch
# 7923
# running_loss
# 0.0013236294034868479
# epoch
# 7924
# running_loss
# 0.0012962807668372989
# epoch
# 7925
# running_loss
# 0.0016643962590023875
# epoch
# 7926
# running_loss
# 0.001453791162930429
# epoch
# 7927
# running_loss
# 0.0015649180859327316
# epoch
# 7928
# running_loss
# 0.0014210063964128494
# epoch
# 7929
# running_loss
# 0.0011231887619942427
# epoch
# 7930
# running_loss
# 0.00128997175488621
# epoch
# 7931
# running_loss
# 0.001592607470229268
# epoch
# 7932
# running_loss
# 0.0011282217456027865
# epoch
# 7933
# running_loss
# 0.0014815691392868757
# epoch
# 7934
# running_loss
# 0.0013901531929150224
# epoch
# 7935
# running_loss
# 0.0011992292711511254
# epoch
# 7936
# running_loss
# 0.0016023569041863084
# epoch
# 7937
# running_loss
# 0.0014059856766834855
# epoch
# 7938
# running_loss
# 0.0011456694919615984
# epoch
# 7939
# running_loss
# 0.0011582361767068505
# epoch
# 7940
# running_loss
# 0.0015645509120076895
# epoch
# 7941
# running_loss
# 0.0014143025036901236
# epoch
# 7942
# running_loss
# 0.0018210855778306723
# epoch
# 7943
# running_loss
# 0.0012309974990785122
# epoch
# 7944
# running_loss
# 0.0018014924135059118
# epoch
# 7945
# running_loss
# 0.0020884305704385042
# epoch
# 7946
# running_loss
# 0.0015372479101642966
# epoch
# 7947
# running_loss
# 0.0015319199301302433
# epoch
# 7948
# running_loss
# 0.00203852541744709
# epoch
# 7949
# running_loss
# 0.0017031024908646941
# epoch
# 7950
# running_loss
# 0.0033866758458316326
# epoch
# 7951
# running_loss
# 0.001349241123534739
# epoch
# 7952
# running_loss
# 0.0015302818501368165
# epoch
# 7953
# running_loss
# 0.0013506534742191434
# epoch
# 7954
# running_loss
# 0.0017649244982749224
# epoch
# 7955
# running_loss
# 0.001426663133315742
# epoch
# 7956
# running_loss
# 0.0013875465374439955
# epoch
# 7957
# running_loss
# 0.001229786081239581
# epoch
# 7958
# running_loss
# 0.0013323902385309339
# epoch
# 7959
# running_loss
# 0.0019220724934712052
# epoch
# 7960
# running_loss
# 0.001275371410883963
# epoch
# 7961
# running_loss
# 0.008456774987280369
# epoch
# 7962
# running_loss
# 0.0026010749861598015
# epoch
# 7963
# running_loss
# 0.0038730748929083347
# epoch
# 7964
# running_loss
# 0.00659616244956851
# epoch
# 7965
# running_loss
# 0.001289996551349759
# epoch
# 7966
# running_loss
# 0.006672827061265707
# epoch
# 7967
# running_loss
# 0.0018164576031267643
# epoch
# 7968
# running_loss
# 0.0014035985805094242
# epoch
# 7969
# running_loss
# 0.001344940741546452
# epoch
# 7970
# running_loss
# 0.005652069114148617
# epoch
# 7971
# running_loss
# 0.0014591757208108902
# epoch
# 7972
# running_loss
# 0.005895194131880999
# epoch
# 7973
# running_loss
# 0.0036089299246668816
# epoch
# 7974
# running_loss
# 0.002578602870926261
# epoch
# 7975
# running_loss
# 0.00236222380772233
# epoch
# 7976
# running_loss
# 0.001479585189372301
# epoch
# 7977
# running_loss
# 0.0052575357258319855
# epoch
# 7978
# running_loss
# 0.0020121585112065077
# epoch
# 7979
# running_loss
# 0.0018694910686463118
# epoch
# 7980
# running_loss
# 0.003646570723503828
# epoch
# 7981
# running_loss
# 0.005585449282079935
# epoch
# 7982
# running_loss
# 0.0029764759819954634
# epoch
# 7983
# running_loss
# 0.001316267647780478
# epoch
# 7984
# running_loss
# 0.0014843273675069213
# epoch
# 7985
# running_loss
# 0.0013903729850426316
# epoch
# 7986
# running_loss
# 0.001540205324999988
# epoch
# 7987
# running_loss
# 0.0014085584552958608
# epoch
# 7988
# running_loss
# 0.0014277209993451834
# epoch
# 7989
# running_loss
# 0.001415458507835865
# epoch
# 7990
# running_loss
# 0.001462732208892703
# epoch
# 7991
# running_loss
# 0.0015774918720126152
# epoch
# 7992
# running_loss
# 0.0013934571761637926
# epoch
# 7993
# running_loss
# 0.0016121540684252977
# epoch
# 7994
# running_loss
# 0.0015476056141778827
# epoch
# 7995
# running_loss
# 0.00151143129914999
# epoch
# 7996
# running_loss
# 0.0014408569550141692
# epoch
# 7997
# running_loss
# 0.0013083424419164658
# epoch
# 7998
# running_loss
# 0.0014562763972207904
# epoch
# 7999
# running_loss
# 0.001315198140218854
# Finished Training 0.001315198140218854 6.744357960997149e-06

# %%
from mpl_toolkits.mplot3d import Axes3D

# Set up meshgrid
N = 600
tspace = np.linspace(lb[0], ub[0], N + 1)
xspace = np.linspace(lb[1], ub[1], N + 1)
T, X = np.meshgrid(tspace, xspace)
Xgrid = np.vstack([T.flatten(),X.flatten()]).T
Xgrid = torch.tensor(Xgrid,dtype=torch.float32)

# Determine predictions of u(t, x)
upred = model(Xgrid)

# Reshape upred
U = upred.detach().numpy().reshape(N+1,N+1)

# Surface plot of solution u(t,x)
fig = plt.figure(figsize=(9,6))
#ax = fig.add_subplot(111, projection='3d')
ax = fig.add_subplot(111)
#ax.plot_surface(T, X, U, cmap='viridis');
ax.contourf(T,X,U)
#ax.view_init(90,0)
ax.set_xlabel('$t$')
ax.set_ylabel('$x$')
#ax.set_zlabel('$u_\\theta(t,x)$')
ax.set_title('Solution of Burgers equation');
#plt.savefig('Burgers_solution.pdf', bbox_inches='tight', dpi=300);

# %%
plt.figure()
plt.contour(X,U,T)
plt.show()

# %%
plt.plot(X[:,450],U[:,450])

# %%
plt.plot(X[:,300],U[:,300])

# %%
plt.plot(X[:,150],U[:,150])

# %%
plt.plot(X[:,0],U[:,0])
