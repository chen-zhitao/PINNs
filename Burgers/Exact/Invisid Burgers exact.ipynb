# %%
from scipy.integrate import quad
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve
from scipy.optimize import root

# %%
def u(x,t):
    def fun(y):
        return x-y+np.sin(np.pi* y)*t
    res = fsolve(fun, x)
    return -np.sin(np.pi* res)

# %%
t=0.32
u_list=[]
for x in np.arange(-1,1.01,0.01):
    u_list.append(u(x,t))

plt.plot(np.arange(-1,1.01,0.01), u_list)
# Out:
# /Users/zchen/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:175: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)
